# %%
import math
import random


pa = [math.log(0.991), math.log(0.003), math.log(0.003), math.log(0.003)]
pg = [math.log(0.001), math.log(0.997), math.log(0.001), math.log(0.001)]
pc = [math.log(0.001), math.log(0.001), math.log(0.997), math.log(0.001)]
pu = [math.log(0.001), math.log(0.001), math.log(0.001), math.log(0.997)]

pw = [math.log(0.499), math.log(0.001), math.log(0.001), math.log(0.499)]
ps = [math.log(0.001), math.log(0.499), math.log(0.499), math.log(0.001)]
pr = [math.log(0.499), math.log(0.499), math.log(0.001), math.log(0.001)]
py = [math.log(0.001), math.log(0.001), math.log(0.499), math.log(0.499)]
pm = [math.log(0.499), math.log(0.001), math.log(0.499), math.log(0.001)]
pk = [math.log(0.001), math.log(0.499), math.log(0.001), math.log(0.499)]

pb = [math.log(0.001), math.log(0.333), math.log(0.333), math.log(0.333)]
pd = [math.log(0.333), math.log(0.001), math.log(0.333), math.log(0.333)]
ph = [math.log(0.333), math.log(0.333), math.log(0.001), math.log(0.333)]
pv = [math.log(0.333), math.log(0.333), math.log(0.333), math.log(0.001)]

pn = [-1.016725, -1.500931, -1.729724, -1.435626]



letter_emis = {"A" : pa, "G" : pg, "C" : pc, "U" : pu, "W" : pw, "S" : ps, "M" : pm, "K" : pk, "R" : pr, "Y" : py, "B" : pb, "D" : pd, "H" : ph, "V" : pv, "N" : pn}
n_emissionsdict = {"A" : pn[0], "G" : pn[1], "C" : pn[2], "U" : pn[3]}


letter_emissionsdict = {}
for el in letter_emis:
    letter_emissionsdict[el] = {"A" : letter_emis[el][0], "G" : letter_emis[el][1], "C" : letter_emis[el][2], "U" : letter_emis[el][3]}




pbpL1 = [-6.299321, -6.431248, -5.777322, -1.953912, -6.405931, -6.937810, -1.355754, -6.896137, -6.143566, -1.148826, -6.553851, -2.372133, -2.030174, -6.357141, -3.197610, -5.959644]
pbpL2 = [-7.256579, -7.767405, -7.256579, -1.957263, -7.256579, -6.563432, -1.302817, -7.767405, -7.767405, -1.362728, -7.256579, -2.612189, -1.678360, -8.866017, -2.765698, -6.032804]

HLlendist = [-math.inf, -15.0, -8.903444, -5.903444, -2.903444, -1.209496, -2.142073, -1.983893, -1.861143, -2.620094, -2.911159, -3.311795, -3.764607, -4.256670, -4.860949, -4.916907, -4.938726, -5.123993, -5.256261, -5.676994, -6.067192, -5.617275, -5.939358, -6.450184, -6.162502, -6.267862, -6.715887, -7.212324, -6.632505, -7.654157, -7.771940, -7.366475]


phlsing = [-1.105321, -1.530578, -1.696738, -1.312284]
pbulgesing = [-0.827097, -1.658819, -1.954306, -1.466825]
pintloopsing = [-0.944122, -1.497648, -1.830329, -1.482969]

qsing_emissionsdict = {"A" : pbulgesing[0], "G" : pbulgesing[1], "C" : pbulgesing[2], "U" : pbulgesing[3]}
Qslendist = [math.log(0.995), math.log(0.004), math.log(0.0005), math.log(0.0003), math.log(0.0002)]

hlsing_emissionsdict = {"A" : phlsing[0], "G" : phlsing[1], "C" : phlsing[2], "U" : phlsing[3]}
bulgesing_emissionsdict = {"A" : pbulgesing[0], "G" : pbulgesing[1], "C" : pbulgesing[2], "U" : pbulgesing[3]}
intloopsing_emissionsdict = {"A" : pintloopsing[0], "G" : pintloopsing[1], "C" : pintloopsing[2], "U" : pintloopsing[3]}

stackedbpF1 = [ 
    [ -3.572346, -4.083171, -2.473733, -1.885947, -3.572346, -5.181784, -1.685276, -5.181784, -5.181784, -2.348570, -5.181784, -3.235873, -1.468211, -5.181784, -2.473733, -3.572346],  
    [ -2.765620, -3.864232, -2.765620, -2.765620, -3.864232, -3.576550, -1.827350, -4.962845, -3.864232, -1.031019, -4.269697, -4.269697, -2.564949, -4.962845, -3.864232, -2.765620],   
    [ -3.670861, -3.670861, -3.419547, -2.481277, -5.616771, -5.616771, -1.427116, -4.518159, -5.616771, -2.120264, -5.616771, -1.197930, -2.481277, -5.616771, -3.670861, -3.419547],   
    [ -7.287034, -8.242546, -7.906074, -1.486079, -7.654759, -9.851984, -1.577372, -7.906074, -7.454088, -1.337996, -7.018770, -3.009300, -1.613183, -7.454088, -2.961375, -8.242546],   
    [ -5.153292, -3.543854, -2.956067, -2.588342, -3.543854, -5.153292, -2.108769, -3.543854, -5.153292, -2.320078, -4.054679, -3.207381, -1.303144, -4.460144, -2.108769, -2.445241],   
    [ -4.330733, -3.232121, -3.232121, -2.721295, -3.637586, -3.637586, -1.932838, -4.330733, -4.330733, -2.251292, -2.721295, -4.330733, -2.944439, -3.232121, -2.384823, -1.386294],   
    [ -7.411059, -8.047047, -7.411059, -1.734305, -6.580710, -8.452512, -1.295816, -6.201221, -7.108778, -1.532170, -7.411059, -3.384657, -1.432471, -8.164830, -2.930385, -7.025396],   
    [ -2.425483, -4.990433, -2.045994, -2.793208, -3.891820, -4.297285, -1.694596, -2.425483, -4.990433, -1.694596, -4.990433, -3.380995, -2.592537, -4.990433, -4.990433, -2.425483],   
    [ -3.357395, -4.204693, -2.905410, -2.258782, -2.905410, -5.303305, -1.936009, -5.303305, -4.610158, -1.453157, -4.204693, -3.106080, -1.692387, -3.357395, -3.106080, -4.204693],   
    [ -7.486778, -7.922096, -6.606419, -2.074345, -8.710554, -10.319992, -1.390424, -10.319992, -6.764643, -1.074960, -7.275469, -2.784161, -1.944362, -8.017406, -2.603085, -7.611941],   
    [ -5.003946, -2.806722, -5.003946, -2.059507, -3.905334, -3.905334, -2.438997, -3.905334, -2.113575, -2.059507, -3.394508, -3.905334, -1.507439, -3.394508, -2.806722, -3.394508],   
    [ -7.962067, -7.114769, -7.962067, -2.003643, -9.060680, -7.962067, -1.169723, -9.060680, -6.662784, -1.193574, -7.114769, -2.511029, -1.975615, -9.060680, -3.618262, -7.451242],   
    [ -6.494973, -7.364011, -6.984521, -1.635661, -6.318042, -7.731736, -1.476839, -7.983050, -7.095747, -1.347104, -6.561665, -3.329090, -1.517795, -7.220910, -2.944244, -7.531065],   
    [ -3.725693, -5.111988, -4.013375, -2.278774, -2.914763, -4.013375, -1.893112, -5.111988, -3.502550, -1.199965, -4.013375, -4.013375, -1.678001, -4.013375, -5.111988, -3.166078],   
    [ -6.535564, -7.634176, -7.634176, -1.886908, -6.334893, -8.732788, -1.293229, -7.634176, -6.535564, -1.641879, -7.634176, -2.013775, -1.826034, -5.899575, -2.595061, -6.334893],   
    [ -4.454347, -4.454347, -3.943522, -2.118972, -5.552960, -4.859812, -1.746297, -5.552960, -3.943522, -1.075623, -3.943522, -3.607049, -2.257123, -3.607049, -3.155064, -2.719746],   
  ]

stackedbpF2 = [ 
    [ -2.258782, -4.204693, -4.204693, -3.106080, -4.204693, -3.106080, -3.106080, -3.511545, -2.258782, -0.908856, -4.204693, -4.204693, -2.595255, -4.204693, -3.106080, -4.204693], 
    [ -3.583519, -3.583519, -3.583519, -3.583519, -3.583519, -3.583519, -2.484907, -3.583519, -3.583519, -0.750306, -3.583519, -2.484907, -3.583519, -3.583519, -3.583519, -3.583519], 
    [ -3.060271, -4.158883, -4.158883, -4.158883, -4.158883, -4.158883, -1.023389, -2.549445, -4.158883, -1.214444, -4.158883, -4.158883, -3.060271, -4.158883, -4.158883, -4.158883],   
    [ -7.277386, -6.321874, -6.488929, -1.873808, -7.500529, -8.886824, -1.364424, -6.178774, -6.940914, -1.058387, -7.277386, -3.357395, -2.140412, -7.277386, -2.532454, -5.842301],   
    [ -4.204693, -4.204693, -4.204693, -4.204693, -2.258782, -4.204693, -0.985817, -4.204693, -4.204693, -1.806797, -4.204693, -3.511545, -2.258782, -3.106080, -3.106080, -4.204693],   
    [ -3.295837, -3.295837, -3.295837, -3.295837, -3.295837, -3.295837, -3.295837, -3.295837, -2.602690, -2.197225, -1.349927, -3.295837, -3.295837, -3.295837, -2.197225, -3.295837],   
    [ -7.268068, -6.632079, -6.757242, -2.072030, -6.287239, -9.465293, -0.843559, -8.772145, -8.366680, -1.641647, -7.673533, -3.570890, -2.051925, -7.519382, -2.446891, -7.519382],   
    [ -3.135494, -3.135494, -3.135494, -2.036882, -3.135494, -3.135494, -3.135494, -2.442347, -3.135494, -2.036882, -3.135494, -3.135494, -2.036882, -3.135494, -3.135494, -3.135494],   
    [ -4.127134, -4.127134, -3.028522, -3.028522, -3.028522, -2.047693, -2.047693, -2.517696, -4.127134, -3.028522, -4.127134, -4.127134, -1.419084, -4.127134, -2.181224, -4.127134],   
    [ -8.578414, -9.677026, -9.677026, -2.270315, -6.121678, -8.578414, -1.264083, -7.112077, -6.843813, -1.079359, -7.597584, -3.396630, -2.001480, -6.904437, -2.312479, -7.279131],   
    [ -4.060443, -4.060443, -4.060443, -1.863218, -2.114533, -1.981001, -1.352393, -4.060443, -4.060443, -4.060443, -2.674149, -4.060443, -4.060443, -3.367296, -3.367296, -2.961831],   
    [ -7.638198, -6.028760, -7.638198, -1.602717, -7.638198, -7.638198, -1.369102, -6.539586, -7.638198, -1.247958, -6.945051, -3.320710, -1.754876, -6.539586, -3.294393, -6.028760],   
    [ -7.844110, -6.109509, -6.996812, -1.910981, -7.844110, -7.844110, -1.148311, -6.745498, -6.109509, -1.389960, -6.996812, -3.245629, -1.810225, -8.942722, -2.613001, -6.745498],   
    [ -3.258097, -3.258097, -3.258097, -1.648659, -2.564949, -3.258097, -3.258097, -3.258097, -3.258097, -3.258097, -1.466337, -3.258097, -3.258097, -3.258097, -3.258097, -3.258097],   
    [ -7.776954, -6.678342, -7.776954, -2.135047, -7.776954, -7.083807, -1.295377, -6.678342, -4.732432, -1.615747, -6.678342, -2.053369, -1.877057, -6.390660, -2.197225, -7.776954],   
    [ -4.025352, -4.025352, -4.025352, -2.926739, -4.025352, -4.025352, -1.317301, -4.025352, -2.079442, -2.415914, -4.025352, -4.025352, -1.317301, -4.025352, -4.025352, -4.025352],   
  ]

Pbulgedist = [-0.563112, -1.526062, -2.392811, -2.928284, -3.225183, -4.458385, -4.449946, -5.024377, -4.416886, -6.521020, -7.149628, -7.031845, -9.229070, -8.535923, -8.535923, -9.229070, -7.842776, -9.229070, -8.130458, -8.535923, -9.229070, -7.619632, -9.229070, -8.130458, -9.229070, -8.130458, -7.283160, -9.229070, -9.229070, -9.229070]
Pintloopdist = [ 
    [-1.406417, -2.902316, -3.650335, -4.933183, -5.920933, -6.818874, -6.965478, -8.118157, -8.118157, -8.811305, -8.523622, -9.216770, -8.523622, -9.216770, -9.216770, -8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917],
    [-3.392246, -2.299064, -3.410130, -5.105896, -4.933183, -6.148717, -7.964007, -7.830475, -8.523622, -7.964007, -8.523622, -6.774423, -8.523622, -9.216770, -8.523622, -8.300479, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917],
    [-3.827698, -3.794025, -2.579512, -3.874435, -5.997894, -3.567795, -7.607332, -7.019545, -7.607332, -8.811305, -8.523622, -9.216770, -8.811305, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.909917, -9.909917, -9.909917],
    [-4.353089, -4.797929, -3.798450, -3.337634, -4.803971, -4.562809, -6.691041, -6.965478, -6.081275, -5.849474, -9.216770, -8.300479, -9.216770, -9.216770, -8.523622, -8.811305, -9.216770, -8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917],
    [-5.114126, -5.455570, -5.105896, -4.307798, -4.318930, -4.750862, -4.968274, -7.512022, -8.300479, -7.425010, -7.712692, -9.216770, -9.216770, -9.216770, -8.300479, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-7.344967, -6.508719, -5.156327, -4.700431, -4.429278, -5.782782, -6.542621, -7.076703, -8.300479, -8.300479, -8.300479, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-7.201867, -7.712692, -6.354569, -6.577712, -5.866866, -5.553208, -7.425010, -6.731863, -7.964007, -8.811305, -7.712692, -8.300479, -8.523622, -8.523622, -8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-7.712692, -6.577712, -7.964007, -7.137328, -8.118157, -5.304747, -7.201867, -6.508719, -7.830475, -8.811305, -8.523622, -9.216770, -8.523622, -9.216770, -9.216770, -9.216770, -8.300479, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.811305, -8.300479, -7.712692, -8.300479, -8.523622, -6.731863, -7.201867, -7.712692, -7.830475, -8.300479, -9.216770, -8.523622, -8.811305, -8.523622, -8.300479, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.300479, -8.300479, -8.523622, -7.270860, -8.523622, -8.118157, -8.300479, -7.964007, -8.300479, -8.118157, -8.523622, -8.811305, -9.216770, -8.300479, -8.811305, -9.216770, -9.216770, -8.300479, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.118157, -7.964007, -9.216770, -6.542621, -7.830475, -8.811305, -8.523622, -8.811305, -7.607332, -8.300479, -8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -8.523622, -9.216770, -7.270860, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -8.811305, -7.964007, -8.118157, -8.118157, -7.964007, -7.270860, -6.965478, -7.712692, -9.216770, -8.811305, -9.216770, -9.216770, -8.300479, -9.216770, -9.216770, -9.216770, -8.811305, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.523622, -8.811305, -9.216770, -7.964007, -8.523622, -7.712692, -8.811305, -8.118157, -7.712692, -8.523622, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -8.811305, -8.300479, -7.830475, -8.523622, -8.523622, -9.216770, -9.216770, -9.216770, -8.811305, -8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -8.811305, -9.216770, -8.811305, -8.811305, -8.811305, -9.216770, -8.523622, -9.216770, -8.523622, -9.216770, -8.118157, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -8.811305, -9.216770, -8.811305, -9.216770, -8.811305, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -8.523622, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -8.811305, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -8.811305, -8.811305, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -8.811305, -8.811305, -8.811305, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.523622, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.216770, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.811305, -9.216770, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-8.523622, -9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.216770, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917],
    [-9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917, -9.909917]
  ]

def intersect(a, b): 
    c = [value for value in a if value in b] 
    return c

N = int(input())

hpPacket = []
for i in range(0, N):
    packet = []
    block = str(input())
    packet.append(block)
    stem = []
    x = str(input())
    y = str(input())
    stem.append(x)
    stem.append(y)
    packet.append(stem)
    hpPacket.append(packet)
    
    
M = int(input())

ilPacket = []
for i in range(0, M):
    packet = []
    block1 = str(input())
    block2 = str(input())
    packet.append([block1, block2])
    stem = []
    x = str(input())
    y = str(input())
    stem.append(x)
    stem.append(y)
    packet.append(stem)
    stem2 = []
    a = str(input())
    b = str(input())
    stem2.append(a)
    stem2.append(b)
    packet.append(stem2)
    ilPacket.append(packet)
    
def ReverseString(string):
    L = len(string)
    rev = ''
    for i in range(1, L+1):
        rev+=string[L - i]
    return rev
    
ilReversePacket = []
for i in range(0, M):
    packet = []
    for el in ilPacket[i][0]:
        if el == "Bulge":
            packet.append(el)
        else:
            packet.append(ReverseString(el))
    ilReversePacket.append([packet])

letter_not = {"A" : ["A"], "G" : ["G"], "C" : ["C"], "U" : ["U"], "W" : ["A", "U"], "S" : ["G", "C"], "M" : ["A", "C"], "K" : ["G", "U"], "R" : ["A", "G"], "Y" : ["C", "U"], "B" : ["C", "G", "U"], "D" : ["A", "G", "U"], "H":["A", "C", "U"], "V":["A", "C", "G"], "N":["A", "G", "C", "U"]}

def stemcov(seq, i, j, L, covp, motifL, motifR):
    ind = 1
    stempairs = []
    for a in range(0, L):
        stempairs.append([i+a, j-a])
    for track in range(0, L):
        if stempairs[track] in covp:
            if seq[stempairs[track][0]] in letter_not[motifL[track]] and seq[stempairs[track][1]] in letter_not[motifR[track]]:
                ind = ind*1
            else:
                ind = ind*0
    return ind
            
    
Mbox = []
for i in range(0, N):
    if len(hpPacket[i][1][0]) == 0:
        Mbox.append({})
    else:
        stlen = len(hpPacket[i][1][0])
        a = []
        for el in n_emissionsdict:
            a.append(el)
        b = a
        while len(b[0]) < 2*stlen:
            c = []
            for el in b:
                for el1 in a:
                    c.append(el+el1)
            b = c
        B = len(b)
        pdict = {}
        stemm = hpPacket[i][1][0] + hpPacket[i][1][1]
        keys = []
        for el in letter_not[stemm[0]]:
            keys.append(el)
        i = 1
        while len(keys[0]) < 2*stlen:
            h = []
            for el in keys:
                for let in letter_not[stemm[i]]:
                    h.append(el+let)
            i+=1
            keys = h
        L = len(keys)
        for seq in b:
            if seq in keys:
                pdict[seq] = math.log(0.99/L)
            else:
                pdict[seq] = math.log(0.01/(B-L))
        Mbox.append(pdict)
        
        
        
        
        
Kbox = []
for i in range(0, M):
    if len(ilPacket[i][1][0]) == 0:
        Kbox.append({})
    else:
        stlen = len(ilPacket[i][1][0])
        a = []
        for el in n_emissionsdict:
            a.append(el)
        b = a
        while len(b[0]) < 2*stlen:
            c = []
            for el in b:
                for el1 in a:
                    c.append(el+el1)
            b = c
        B = len(b)
        pdict = {}
        stemm = ilPacket[i][1][0] + ilPacket[i][1][1]
        keys = []
        for el in letter_not[stemm[0]]:
            keys.append(el)
        i = 1
        while len(keys[0]) < 2*stlen:
            h = []
            for el in keys:
                for let in letter_not[stemm[i]]:
                    h.append(el+let)
            i+=1
            keys = h
        L = len(keys)
        for seq in b:
            if seq in keys:
                pdict[seq] = math.log(0.999/L)
            else:
                pdict[seq] = math.log(0.001/(B-L))
        Kbox.append(pdict)
        
        
K2box = []
for i in range(0, M):
    if len(ilPacket[i][2][0]) == 0:
        K2box.append({})
    else:
        stlen = len(ilPacket[i][2][0])
        a = []
        for el in n_emissionsdict:
            a.append(el)
        b = a
        while len(b[0]) < 2*stlen:
            c = []
            for el in b:
                for el1 in a:
                    c.append(el+el1)
            b = c
        B = len(b)
        pdict = {}
        stemm = ilPacket[i][2][0] + ilPacket[i][2][1]
        keys = []
        for el in letter_not[stemm[0]]:
            keys.append(el)
        i = 1
        while len(keys[0]) < 2*stlen:
            h = []
            for el in keys:
                for let in letter_not[stemm[i]]:
                    h.append(el+let)
            i+=1
            keys = h
        L = len(keys)
        for seq in b:
            if seq in keys:
                pdict[seq] = math.log(0.999/L)
            else:
                pdict[seq] = math.log(0.001/(B-L))
        K2box.append(pdict)
        

letter_set = []
for el in hpPacket:
    for let in el[0][:-1]:
        letter_set.append(let)
letter_set = set(letter_set)



illetter_set = []
for el in ilPacket:
    for block in el[0]:
        if block != "Bulge":
            for let in block:
                illetter_set.append(let)
illetter_set = set(illetter_set)            
            

pMotifNT = [math.log(0.9995), math.log(0.00025), math.log(0.00025)]
pMotifT = [math.log(0.998), math.log(0.002)]
pInOut = [math.log(0.5), math.log(0.5)]
pLeftRight = [math.log(0.5), math.log(0.5)]



pS = [-0.223274, -2.139489, -2.496295]
pL = [-0.136271, -2.060474]
pF = [-0.353167, -1.212207]
pM = [-0.876334, -0.538379]
pR = [-0.238314, -1.550958]
pM1 = [-0.200071, -1.707450]
pP = [-2.370805, -2.370805, -1.082283, -1.048927, -2.087036]
pHL2 = [math.log(0.006), math.log(0.994)]
pInsert = [math.log(0.05), math.log(0.95)]

pHL = [math.log(0.98)]
for i in range(0, N):
    pHL.append(math.log(0.02/N))
    
    
    

PP = []
for el in pP:
    PP.append(math.log(0.98*math.exp(el)))
    for i in range(0, M):
        PP.append(math.log(0.02/M))
pP = PP
    
    
    
bplist = ["AA", "AC", "AG", "AU", "CA", "CC", "CG", "CU", "GA", "GC", "GG", "GU", "UA", "UC", "UG", "UU"]
def bptonum(bp):
    charbp = bp
    for i in range(0, 16):
        if charbp == bplist[i]:
            return i



def listtostr(arr):
    st = ""
    for el in arr:
        st+=el
    return st



def covcomplete(i, j, covpairs):
    if covpairs == []:
        return 1
    else:
        pset = []
        for el in covpairs:
            if i <= el[0] <= j and i <= el[1] <= j:
                pset.append(1)
            elif el[1] < i:
                pset.append(1)
            elif el[0] > j:
                pset.append(1)
            elif el[0] < i and el[1] > j:
                pset.append(1)
            else:
                pset.append(0)
        prod = 1
        for el in pset:
            prod = prod*el
        return prod

def searchcov(i, j, covlist, covpairs):
    if covpairs == []:
        return 0
    else:
        sch = 0
        for el in covlist:
            if i <= el <= j:
                sch = 1
        return sch




def parsesequence(RNAsequence, covpairs, restrictbp):
    Anum = RNAsequence.count("A")
    Gnum = RNAsequence.count("G")
    Cnum = RNAsequence.count("C")
    Unum = RNAsequence.count("U")
    Nnum = Anum + Gnum + Cnum + Unum
    if RNAsequence == "":
        return None
    elif Nnum != len(RNAsequence):
        return None    
    else:
        if covpairs == []:
            covlist = []
            lcov = []
            rcov = []
        else:
            lcov = []
            rcov = []
            covlist = []
            for el in covpairs:
                lcov.append(el[0])
                rcov.append(el[1])
                covlist.append(el[0])
                covlist.append(el[1])
        
        n = len(RNAsequence)
        maxlogpS = []
        maxlogpL = []
        maxlogpF = []
        maxlogpP = []
        maxlogpHL = []
        maxlogpHL2 = []
        maxlogpM = []
        maxlogpR = []
        maxlogpM1 = []
        maxlogphploopMotifs = []
        for t in range(0, N):
            maxlogphploopMotifs.append([])
        maxlogpcontigMC = []
        for t in range(0, N):
            L = len(hpPacket[t][0])
            hlMi = []
            for g in range(0, L):
                hlMi.append([])
            maxlogpcontigMC.append(hlMi)
        maxlogpinsertMC = {}
        for let in letter_set:
            maxlogpinsertMC[let] = []
        maxlogpilloopMotifs = []
        for t in range(0, M):
            maxlogpilloopMotifs.append([])
        maxlogpblockMCG = []
        for t in range(0, M):
            doub = []
            for el in ilPacket[t][0]:
                hlmi = []
                for g in range(0, len(el)):
                    hlmi.append([])
                doub.append(hlmi)
            maxlogpblockMCG.append(doub)
        maxlogpblockMCB = []
        for t in range(0, M):
            doub = []
            for el in ilPacket[t][0]:
                hlmi = []
                for g in range(0, len(el)):
                    hlmi.append([])
                doub.append(hlmi)
            maxlogpblockMCB.append(doub)
        maxlogpinsertMCIL = {}
        for let in illetter_set:
            maxlogpinsertMCIL[let] = []  
        maxlogpilMotifIO = []
        for t in range(0, M):
            maxlogpilMotifIO.append([[], []])
        maxlogpilMotifILR = []
        for t in range(0, M):
            maxlogpilMotifILR.append([[], []])
        maxlogpilMotifOLR = []
        for t in range(0, M):
            maxlogpilMotifOLR.append([[], []])
        maxlogportL = []
        for t in range(0, M):
                maxlogportL.append([[], []])
        maxlogportO = []
        for t in range(0, M):
                maxlogportO.append([[], []])
        for j in range(0, n):
            maxlogpSj = []
            maxlogpLj = []
            maxlogpFj = []
            maxlogpPj = []
            maxlogpHLj = []
            maxlogpHL2j = []
            maxlogpMj = []
            maxlogpRj = []
            maxlogpM1j = []
            maxlogphploopMotifsj = []
            for t in range(0, N):
                maxlogphploopMotifsj.append([])
            maxlogpcontigMCj = []
            for t in range(0, N):
                L = len(hpPacket[t][0])
                hlMi = []
                for g in range(0, L):
                    hlMi.append([])
                maxlogpcontigMCj.append(hlMi)
            maxlogpinsertMCj = {}
            for let in letter_set:
                maxlogpinsertMCj[let] = []
            maxlogpilloopMotifsj = []
            for t in range(0, M):
                maxlogpilloopMotifsj.append([])
            maxlogpblockMCGj = []
            for t in range(0, M):
                doub = []
                for el in ilPacket[t][0]:
                    hlmi = []
                    for g in range(0, len(el)):
                        hlmi.append([])
                    doub.append(hlmi)
                maxlogpblockMCGj.append(doub)
            maxlogpblockMCBj = []
            for t in range(0, M):
                doub = []
                for el in ilPacket[t][0]:
                    hlmi = []
                    for g in range(0, len(el)):
                        hlmi.append([])
                    doub.append(hlmi)
                maxlogpblockMCBj.append(doub)
            maxlogpinsertMCILj = {}
            for let in illetter_set:
                maxlogpinsertMCILj[let] = []  
            maxlogpilMotifIOj = []
            for t in range(0, M):
                maxlogpilMotifIOj.append([[], []])
            maxlogpilMotifILRj = []
            for t in range(0, M):
                maxlogpilMotifILRj.append([[], []])
            maxlogpilMotifOLRj = []
            for t in range(0, M):
                maxlogpilMotifOLRj.append([[], []])
            maxlogportLj = []
            for t in range(0, M):
                maxlogportLj.append([[], []])
            maxlogportOj = []
            for t in range(0, M):
                maxlogportOj.append([[], []])
            maxlogpSj.append(pS[2])
            maxlogpLj.append(-math.inf)
            maxlogpFj.append(-math.inf)
            maxlogpHL2j.append(pHL2[1])
            maxlogpMj.append(-math.inf)
            maxlogpRj.append(-math.inf)
            maxlogpM1j.append(-math.inf)
            for let in letter_set:
                maxlogpinsertMCj[let].append(-math.inf)
            for let in illetter_set:
                maxlogpinsertMCILj[let].append(-math.inf)
            for t in range(0, M):
                maxlogpilloopMotifsj[t].append(-math.inf)
            for t in range(0, M):
                maxlogpilMotifIOj[t][0].append(-math.inf)
                maxlogpilMotifIOj[t][1].append(-math.inf)
            for t in range(0, M):
                maxlogpilMotifILRj[t][0].append(-math.inf)
                maxlogpilMotifILRj[t][1].append(-math.inf)
            for t in range(0, M):
                maxlogpilMotifOLRj[t][0].append(-math.inf)
                maxlogpilMotifOLRj[t][1].append(-math.inf)                
            for t in range(0, N):
                for g in range(0, len(hpPacket[t][0])):
                    if g == 0:
                        maxlogpcontigMCj[t][g].append(pMotifT[1])
                    else:
                        maxlogpcontigMCj[t][g].append(pMotifNT[1]*g + pMotifT[1])
            for t in range(0, N):
                if len(hpPacket[t][1][0]) > 0:
                    maxlogphploopMotifsj[t].append(-math.inf)
                else:
                    maxlogphploopMotifsj[t].append(pHL2[1] + maxlogpcontigMCj[t][len(hpPacket[t][0])-1][0])
            tot = []
            for t in range(0, N):
                tot.append(maxlogphploopMotifsj[t][0] + pHL[t+1])
            maxlogpHLj.append(max(tot))
            for t in range(0, M):
                for el in range(0, 2):
                    if ilPacket[t][0][el] != "Bulge":
                        for g in range(0, len(ilPacket[t][0][el])):
                            if g == 0:
                                maxlogpblockMCGj[t][el][g].append(pMotifT[1])
                            else:
                                maxlogpblockMCGj[t][el][g].append(pMotifNT[1]*g + pMotifT[1])
            for t in range(0, M):
                for el in range(0, 2):
                    if ilReversePacket[t][0][el] != "Bulge":
                        for g in range(0, len(ilReversePacket[t][0][el])):
                            if g == 0:
                                maxlogpblockMCBj[t][el][g].append(pMotifT[1])
                            else:
                                maxlogpblockMCBj[t][el][g].append(pMotifNT[1]*g + pMotifT[1])           
            maxlogpPj.append(pP[3] + maxlogpHLj[0])
            for t in range(0, M):
                maxlogportLj[t][0].append(-math.inf)
                maxlogportLj[t][1].append(-math.inf)
            for t in range(0, M):
                maxlogportOj[t][0].append(-math.inf)
                maxlogportOj[t][1].append(-math.inf)
            for d in range(1, j+2):
                i = j-d+1
                if covcomplete(i, j, covpairs) == 0:
                    maxlogpSj.append(-math.inf)
                    maxlogpLj.append(-math.inf)
                    maxlogpFj.append(-math.inf)
                    maxlogpPj.append(-math.inf)
                    maxlogpHLj.append(-math.inf)
                    maxlogpHL2j.append(-math.inf)
                    maxlogpMj.append(-math.inf)
                    maxlogpRj.append(-math.inf)
                    maxlogpM1j.append(-math.inf)
                    for let in letter_set:
                        maxlogpinsertMCj[let].append(-math.inf)
                    for t in range(0, N):
                        maxlogphploopMotifsj[t].append(-math.inf)
                    for t in range(0, N):
                        for g in range(0, len(hpPacket[t][0])):
                            maxlogpcontigMCj[t][g].append(-math.inf)
                    for let in illetter_set:
                        maxlogpinsertMCILj[let].append(-math.inf)        
                    for t in range(0, M):
                        maxlogpilloopMotifsj[t].append(-math.inf)
                    for t in range(0, M):
                        maxlogpilMotifIOj[t][0].append(-math.inf)
                        maxlogpilMotifIOj[t][1].append(-math.inf)
                    for t in range(0, M):
                        maxlogpilMotifILRj[t][0].append(-math.inf)
                        maxlogpilMotifILRj[t][1].append(-math.inf)
                    for t in range(0, M):
                        maxlogpilMotifOLRj[t][0].append(-math.inf)
                        maxlogpilMotifOLRj[t][1].append(-math.inf)
                    for t in range(0, M):
                        maxlogportLj[t][0].append(-math.inf)
                        maxlogportLj[t][1].append(-math.inf)
                    for t in range(0, M):
                        maxlogportOj[t][0].append(-math.inf)
                        maxlogportOj[t][1].append(-math.inf)
                    for t in range(0, M):
                        for el in range(0, 2):
                            if ilPacket[t][0][el] != "Bulge":
                                for g in range(0, len(ilPacket[t][0][el])):
                                    maxlogpblockMCGj[t][el][g].append(-math.inf)
                    for t in range(0, M):
                        for el in range(0, 2):
                            if ilReversePacket[t][0][el] != "Bulge":
                                for g in range(0, len(ilReversePacket[t][0][el])):
                                    maxlogpblockMCBj[t][el][g].append(-math.inf)        
                else:
                    if d == 1:
                        #S
                        maxlogpSd = pS[0] + n_emissionsdict[RNAsequence[i]] + pS[2]
                        maxlogpSj.append(maxlogpSd)
                        #L
                        maxlogpLd = -math.inf
                        maxlogpLj.append(maxlogpLd)
                        #F
                        maxlogpFd = -math.inf
                        maxlogpFj.append(maxlogpFd)
                        #Insertions
                        for let in letter_set:
                            maxlogpinsertMCj[let].append(pInsert[1] + letter_emissionsdict["N"][RNAsequence[i]])
                        #ILInsertions
                        for let in illetter_set:
                            maxlogpinsertMCILj[let].append(pInsert[1] + letter_emissionsdict["N"][RNAsequence[i]])
                        #M1
                        maxlogpM1d = -math.inf
                        maxlogpM1j.append(maxlogpM1d)
                        #R
                        maxlogpRd = -math.inf
                        maxlogpRj.append(maxlogpRd)
                        #M
                        maxlogpMd = -math.inf
                        maxlogpMj.append(maxlogpMd)
                        #Contiguous Blocks
                        for t in range(0, N):
                            for g in range(0, len(hpPacket[t][0])):
                                if g == 0:
                                    maxlogpcontigMCj[t][g].append(pMotifT[0] + letter_emissionsdict[hpPacket[t][0][-1]][RNAsequence[i]])
                                else:
                                    maxlogpcontigd = pMotifNT[0] + letter_emissionsdict[hpPacket[t][0][-1-g]][RNAsequence[i]] + maxlogpcontigMCj[t][g-1][0]
                                    psplit = pMotifNT[1] + maxlogpcontigMCj[t][g-1][1]
                                    if psplit > maxlogpcontigd:
                                        maxlogpcontigd = psplit
                                    maxlogpcontigMCj[t][g].append(maxlogpcontigd)
                        #Straight Blocks
                        for t in range(0, M):
                            for el in range(0, 2):
                                if ilPacket[t][0][el] != "Bulge":
                                    for g in range(0, len(ilPacket[t][0][el])):
                                        if g == 0:
                                            maxlogpblockMCGj[t][el][g].append(pMotifT[0] + letter_emissionsdict[ilPacket[t][0][el][-1]][RNAsequence[i]])
                                        else:
                                            maxlogpcontigd = pMotifNT[0] + letter_emissionsdict[ilPacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpblockMCGj[t][el][g-1][0]
                                            psplit = pMotifNT[1] + maxlogpblockMCGj[t][el][g-1][1]
                                            if psplit > maxlogpcontigd:
                                                maxlogpcontigd = psplit
                                            maxlogpblockMCGj[t][el][g].append(maxlogpcontigd)                     
                        #Reverse Blocks
                        for t in range(0, M):
                            for el in range(0, 2):
                                if ilReversePacket[t][0][el] != "Bulge":
                                    for g in range(0, len(ilReversePacket[t][0][el])):
                                        if g == 0:
                                            maxlogpblockMCBj[t][el][g].append(pMotifT[0] + letter_emissionsdict[ilReversePacket[t][0][el][-1]][RNAsequence[i]])
                                        else:
                                            maxlogpcontigd = pMotifNT[0] + letter_emissionsdict[ilReversePacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpblockMCBj[t][el][g-1][0]
                                            psplit = pMotifNT[1] + maxlogpblockMCBj[t][el][g-1][1]
                                            if psplit > maxlogpcontigd:
                                                maxlogpcontigd = psplit
                                            maxlogpblockMCBj[t][el][g].append(maxlogpcontigd)
                        #HL2
                        maxlogpHL2d = pHL2[0] + n_emissionsdict[RNAsequence[i]] + maxlogpHL2j[0]
                        maxlogpHL2j.append(maxlogpHL2d)
                        #HLMotifs
                        for t in range(0, N):
                            if len(hpPacket[t][1][0]) > 0:
                                maxlogphploopMotifsj[t].append(-math.inf)
                            else:
                                maxlogpmotifd = -math.inf
                                psplit = maxlogpcontigMCj[t][len(hpPacket[t][0])-1][d] + maxlogpHL2j[0]
                                if psplit > maxlogpmotifd:
                                    maxlogpmotifd = psplit
                                psplit = maxlogpcontigMCj[t][len(hpPacket[t][0])-1][0] + maxlogpHL2j[d]
                                if psplit > maxlogpmotifd:
                                    maxlogpmotifd = psplit
                                maxlogphploopMotifsj[t].append(maxlogpmotifd)
                        #ILMotifs
                        for t in range(0, M):
                            maxlogpilloopMotifsj[t].append(-math.inf)
                        #ILIO
                        for t in range(0, M):
                            maxlogpilMotifIOj[t][0].append(-math.inf)
                            maxlogpilMotifIOj[t][1].append(-math.inf)
                        #ILILR
                        for t in range(0, M):
                            maxlogpilMotifILRj[t][0].append(-math.inf)
                            maxlogpilMotifILRj[t][1].append(-math.inf)
                        #ILOLR
                        for t in range(0, M):
                            maxlogpilMotifOLRj[t][0].append(-math.inf)
                            maxlogpilMotifOLRj[t][1].append(-math.inf) 
                        #Oriented L
                        for t in range(0, M):
                            maxlogportLj[t][0].append(-math.inf)
                            maxlogportLj[t][1].append(-math.inf)
                        #Oriented O
                        for t in range(0, M):
                            maxlogportOj[t][0].append(-math.inf)
                            maxlogportOj[t][1].append(-math.inf)
                        #HL
                        totset = []
                        for t in range(0, N):
                            totset.append(maxlogphploopMotifsj[t][d] + pHL[t+1])
                        maxlogpHLj.append(max(totset))                        
                        #P
                        maxlogpPd = pP[3] + maxlogpHLj[d]
                        maxlogpPj.append(maxlogpPd)
                    else:
                        maxlogpSd = -math.inf
                        maxlogpLd = -math.inf
                        maxlogpFd = -math.inf
                        maxlogpPd = -math.inf
                        maxlogpHLd = -math.inf
                        maxlogpHL2d = -math.inf
                        maxlogpMd = -math.inf
                        maxlogpRd = -math.inf
                        maxlogpM1d = -math.inf
                        #F
                        if [i, j] in restrictbp:
                            maxlogpFj.append(-math.inf)
                        else:
                            if [i, j] not in covpairs and i in lcov and j in rcov:
                                maxlogpFd = -math.inf
                            elif [i, j] not in covpairs and i not in lcov and j in rcov:
                                maxlogpFd = -math.inf
                            elif [i, j] not in covpairs and i in lcov and j not in rcov:
                                maxlogpFd = -math.inf
                            else:
                                if i == 0 or j == n-1:
                                    maxlogpFd = -math.inf
                                else:
                                    key = bptonum(RNAsequence[i-1] + RNAsequence[j+1])
                                    key1 = bptonum(RNAsequence[i] + RNAsequence[j])
                                    psplit = maxlogpF[j-1][d-2] + stackedbpF1[key][key1] + pF[0]
                                    if psplit > maxlogpFd:
                                        maxlogpFd = psplit
                                    psplit = maxlogpP[j-1][d-2] + stackedbpF2[key][key1] + pF[1]
                                    if psplit > maxlogpFd:
                                        maxlogpFd = psplit              
                            maxlogpFj.append(maxlogpFd)
                        #L
                        if [i, j] in restrictbp:
                            maxlogpLj.append(-math.inf)
                        else:
                            if [i, j] not in covpairs and i in lcov and j in rcov:
                                maxlogpLd = -math.inf
                            elif [i, j] not in covpairs and i not in lcov and j in rcov:
                                maxlogpLd = -math.inf
                            elif [i, j] not in covpairs and i in lcov and j not in rcov:
                                maxlogpLd = -math.inf
                            else:
                                if d == 2:            
                                    psplit = maxlogpPj[0] + pbpL2[bptonum(RNAsequence[i] + RNAsequence[j])] + pL[1]                                            
                                    if psplit > maxlogpLd:
                                        maxlogpLd = psplit
                                else:
                                    psplit = maxlogpF[j-1][d-2] + pbpL1[bptonum(RNAsequence[i] + RNAsequence[j])] + pL[0]
                                    if psplit > maxlogpLd:
                                        maxlogpLd = psplit
                                    psplit = maxlogpP[j-1][d-2] + pbpL2[bptonum(RNAsequence[i] + RNAsequence[j])] + pL[1]
                                    if psplit > maxlogpLd:
                                        maxlogpLd = psplit
                            maxlogpLj.append(maxlogpLd)
                        #Insertions
                        for let in letter_set:
                            maxlogpinsertd = -math.inf
                            if i in lcov:
                                maxlogpinsertMCj[let].append(-math.inf)
                            else:
                                psplit = maxlogpinsertMCj[let][d-1] + letter_emissionsdict["N"][RNAsequence[i]] + pInsert[0]
                                if psplit > maxlogpinsertd:
                                    maxlogpinsertd = psplit
                                maxlogpinsertMCj[let].append(maxlogpinsertd)       
                        #ILInsertions
                        for let in illetter_set:
                            maxlogpinsertd = -math.inf
                            if i in lcov:
                                maxlogpinsertMCILj[let].append(-math.inf)
                            else:
                                psplit = maxlogpinsertMCILj[let][d-1] + letter_emissionsdict["N"][RNAsequence[i]] + pInsert[0]
                                if psplit > maxlogpinsertd:
                                    maxlogpinsertd = psplit
                                maxlogpinsertMCILj[let].append(maxlogpinsertd)
                        #Oriented L
                        for t in range(0, M):
                            if len(ilPacket[t][2][0]) == 0:
                                maxlogportLj[t][0].append(maxlogpLd)
                                maxlogportLj[t][1].append(maxlogpLd)
                            else:
                                L = len(ilPacket[t][2][0])
                                maxlogportLLd = -math.inf
                                maxlogportLRd = -math.inf
                                if stemcov(RNAsequence, i, j, L, covpairs, ilPacket[t][2][0], ilPacket[t][2][1]) == 1:
                                    if d > 2*L:
                                        stemL = ""
                                        stemR = ""
                                        for q in range(0, L):
                                            stemL+=RNAsequence[i+q]
                                        for q in range(L-1, -1, -1):    
                                            stemR+=RNAsequence[j-q]
                                        stemcode = stemL+stemR
                                        maxlogportLLd = K2box[t][stemcode] + maxlogpL[j-L][d - 2*L]
                                if stemcov(RNAsequence, i, j, L, covpairs, ReverseString(ilPacket[t][2][1]), ReverseString(ilPacket[t][2][0])) == 1:
                                    if d > 2*L:
                                        stemL = ""
                                        stemR = ""
                                        for q in range(0, L):
                                            stemL+=RNAsequence[i+q]
                                        for q in range(L-1, -1, -1):    
                                            stemR+=RNAsequence[j-q]
                                        stemcode = stemL+stemR
                                        maxlogportLRd = K2box[t][ReverseString(stemcode)] + maxlogpL[j-L][d - 2*L]
                                maxlogportLj[t][0].append(maxlogportLLd)
                                maxlogportLj[t][1].append(maxlogportLRd)
                        #S
                        if i in lcov:
                            maxlogpSd = -math.inf
                        else:
                            psplit = maxlogpSj[d-1] + n_emissionsdict[RNAsequence[i]] + pS[0]
                            if psplit > maxlogpSd:
                                maxlogpSd = psplit
                        for s in range(0, d-1):
                            psplit = maxlogpL[i+s][s+1] + maxlogpSj[d-1-s] + pS[1]   
                            if psplit > maxlogpSd:
                                maxlogpSd = psplit
                        psplit = maxlogpLd + maxlogpSj[0] + pS[1]
                        if psplit > maxlogpSd:
                            maxlogpSd = psplit
                        maxlogpSj.append(maxlogpSd)
                        #M1
                        if i in lcov:
                            maxlogpM1d = -math.inf
                        else:
                            psplit = maxlogpM1j[d-1] + n_emissionsdict[RNAsequence[i]] + pM1[0]
                            if psplit > maxlogpM1d:
                                maxlogpM1d = psplit
                        psplit = maxlogpLd + pM1[1]
                        if psplit > maxlogpM1d:
                            maxlogpM1d = psplit
                        maxlogpM1j.append(maxlogpM1d)
                        #R
                        if j in rcov:
                            maxlogpRd = -math.inf
                        else:
                            psplit = maxlogpR[j-1][d-1] + n_emissionsdict[RNAsequence[j]] + pR[0]
                            if psplit > maxlogpRd:
                                maxlogpRd = psplit
                        psplit = maxlogpM1d + pR[1]
                        if psplit > maxlogpRd:
                            maxlogpRd = psplit
                        maxlogpRj.append(maxlogpRd)
                        #M
                        for s in range(0, d-1):
                            psplit = maxlogpM1[i+s][s+1] + maxlogpMj[d-1-s] + pM[0]
                            if psplit > maxlogpMd:
                                maxlogpMd = psplit
                        psplit = maxlogpRd + pM[1]
                        if psplit > maxlogpMd:
                            maxlogpMd = psplit
                        maxlogpMj.append(maxlogpMd)
                        #Contiguous Blocks
                        for t in range(0, N):
                            for g in range(0, len(hpPacket[t][0])):
                                if g == 0:
                                    maxlogpcontigMCj[t][g].append(-math.inf)
                                else:
                                    if i in lcov:
                                        maxlogpcontigd = -math.inf
                                    else:
                                        maxlogpcontigd = -math.inf
                                        psplit = maxlogpcontigMCj[t][g-1][d-1] + letter_emissionsdict[hpPacket[t][0][-1-g]][RNAsequence[i]] + pMotifNT[0]
                                        if psplit > maxlogpcontigd:
                                            maxlogpcontigd = psplit
                                        if d == 2:
                                            pass
                                        else:
                                            for s in range(0, d-2):
                                                psplit = letter_emissionsdict[hpPacket[t][0][-1-g]][RNAsequence[i]] + maxlogpinsertMC[hpPacket[t][0][-1-g]][i+s+1][s+1] + maxlogpcontigMCj[t][g-1][d-s-2] + pMotifNT[2]
                                                if psplit > maxlogpcontigd:
                                                    maxlogpcontigd = psplit
                                        psplit = letter_emissionsdict[hpPacket[t][0][-1-g]][RNAsequence[i]] + maxlogpinsertMCj[hpPacket[t][0][-1-g]][d-1] + maxlogpcontigMCj[t][g-1][0] + pMotifNT[2]
                                        if psplit > maxlogpcontigd:
                                            maxlogpcontigd = psplit
                                    psplit = maxlogpcontigMCj[t][g-1][d] + pMotifNT[1]
                                    if psplit > maxlogpcontigd:
                                        maxlogpcontigd = psplit
                                    maxlogpcontigMCj[t][g].append(maxlogpcontigd)
                        #Straight Blocks
                        for t in range(0, M):
                            for el in range(0, 2):
                                if ilPacket[t][0][el] != "Bulge":
                                    for g in range(0, len(ilPacket[t][0][el])):
                                        if g == 0:
                                            maxlogpblockMCGj[t][el][g].append(-math.inf)
                                        else:
                                            if i in lcov:
                                                maxlogpcontigd = -math.inf
                                            else:
                                                maxlogpcontigd = -math.inf
                                                psplit = maxlogpblockMCGj[t][el][g-1][d-1] + letter_emissionsdict[ilPacket[t][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0]
                                                if psplit > maxlogpcontigd:
                                                    maxlogpcontigd = psplit
                                                if d == 2:
                                                    pass
                                                else:
                                                    for s in range(0, d-2):
                                                        psplit = letter_emissionsdict[ilPacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilPacket[t][0][el][-1-g]][i+s+1][s+1] + maxlogpblockMCGj[t][el][g-1][d-s-2] + pMotifNT[2]
                                                        if psplit > maxlogpcontigd:
                                                            maxlogpcontigd = psplit
                                                psplit = letter_emissionsdict[ilPacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCILj[ilPacket[t][0][el][-1-g]][d-1] + maxlogpblockMCGj[t][el][g-1][0] + pMotifNT[2]
                                                if psplit > maxlogpcontigd:
                                                    maxlogpcontigd = psplit
                                            psplit = maxlogpblockMCGj[t][el][g-1][d] + pMotifNT[1]
                                            if psplit > maxlogpcontigd:
                                                maxlogpcontigd = psplit
                                            maxlogpblockMCGj[t][el][g].append(maxlogpcontigd)                      
                        #Reverse Blocks
                        for t in range(0, M):
                            for el in range(0, 2):
                                if ilReversePacket[t][0][el] != "Bulge":
                                    for g in range(0, len(ilReversePacket[t][0][el])):
                                        if g == 0:
                                            maxlogpblockMCBj[t][el][g].append(-math.inf)
                                        else:
                                            if i in lcov:
                                                maxlogpcontigd = -math.inf
                                            else:
                                                maxlogpcontigd = -math.inf
                                                psplit = maxlogpblockMCBj[t][el][g-1][d-1] + letter_emissionsdict[ilReversePacket[t][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0]
                                                if psplit > maxlogpcontigd:
                                                    maxlogpcontigd = psplit
                                                if d == 2:
                                                    pass
                                                else:
                                                    for s in range(0, d-2):
                                                        psplit = letter_emissionsdict[ilReversePacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilReversePacket[t][0][el][-1-g]][i+s+1][s+1] + maxlogpblockMCBj[t][el][g-1][d-s-2] + pMotifNT[2]
                                                        if psplit > maxlogpcontigd:
                                                            maxlogpcontigd = psplit
                                                psplit = letter_emissionsdict[ilReversePacket[t][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCILj[ilReversePacket[t][0][el][-1-g]][d-1] + maxlogpblockMCBj[t][el][g-1][0] + pMotifNT[2]
                                                if psplit > maxlogpcontigd:
                                                    maxlogpcontigd = psplit
                                            psplit = maxlogpblockMCBj[t][el][g-1][d] + pMotifNT[1]
                                            if psplit > maxlogpcontigd:
                                                maxlogpcontigd = psplit
                                            maxlogpblockMCBj[t][el][g].append(maxlogpcontigd)         
                        #ILILR
                        for t in range(0, M):
                            maxlogpILd = -math.inf
                            maxlogpIRd = -math.inf
                            if ilPacket[t][0][0] == "Bulge" and ilPacket[t][0][1] != "Bulge":
                                #IL
                                if i in lcov:
                                    maxlogpILd = -math.inf
                                else:
                                    for s in range(0, d):
                                        psplit = maxlogportL[t][0][i+s-1][s] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][d-s] + Qslendist[0]
                                        if psplit > maxlogpILd:
                                            maxlogpILd = psplit
                                    psplit = maxlogportLj[t][0][d] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + Qslendist[0]
                                    if psplit > maxlogpILd:
                                        maxlogpILd = psplit
                                    for x in range(i+1, j):
                                        if x-i < 5:
                                            for y in range(x+1, j):
                                                if searchcov(i, x-1, covlist, covpairs) == 0:
                                                    psplit = maxlogportL[t][0][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][j-y]
                                                    for nlt in RNAsequence[i:x]:
                                                        psplit += qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpILd:
                                                        maxlogpILd = psplit
                                    for s in range(1, min(d, 5)):
                                        if searchcov(i, i+s-1, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogportLj[t][0][d-s] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0]
                                            for nlt in RNAsequence[i:i+s]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpILd:
                                                maxlogpILd = psplit
                                
                                #IR
                                if j in rcov:
                                    maxlogpIRd = -math.inf
                                else:
                                    for s in range(1, min(d, 5)):
                                        if searchcov(j-s+1, j, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogportL[t][1][j-s][d-s] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0]
                                            for nlt in RNAsequence[j-s+1:j+1]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpIRd:
                                                maxlogpIRd = psplit
                                    psplit = maxlogportLj[t][1][d] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0] + Qslendist[0]
                                    if psplit > maxlogpIRd:
                                        maxlogpIRd = psplit
                                    for x in range(i+1, j):
                                        for y in range(x+1, j):
                                            if j-y < 5:
                                                if searchcov(y+1, j, covlist, covpairs) == 0:
                                                    psplit = maxlogportL[t][1][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCB[t][1][len(ilReversePacket[t][0][1])-1][x-1][x-i]
                                                    for nlt in RNAsequence[y+1:j+1]:
                                                        psplit+=qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpIRd:
                                                        maxlogpIRd = psplit
                                    for s in range(1, d):
                                        psplit = maxlogpblockMCB[t][1][len(ilReversePacket[t][0][1])-1][i+s-1][s] + maxlogportLj[t][1][d-s] + Qslendist[0]
                                        if psplit > maxlogpIRd:
                                            maxlogpIRd = psplit
                            if ilPacket[t][0][0] != "Bulge" and ilPacket[t][0][1] == "Bulge":
                                #IL
                                if j in rcov:
                                    maxlogpILd = -math.inf
                                else:
                                    for s in range(1, min(d, 5)):
                                        if searchcov(j-s+1, j, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogportL[t][0][j-s][d-s] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0]
                                            for nlt in RNAsequence[j-s+1:j+1]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpILd:
                                                maxlogpILd = psplit
                                    psplit = maxlogportLj[t][0][d] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + Qslendist[0]
                                    if psplit > maxlogpILd:
                                        maxlogpILd = psplit
                                    for x in range(i+1, j):
                                        for y in range(x+1, j):
                                            if j-y < 5:
                                                if searchcov(y+1, j, covlist, covpairs) == 0:
                                                    psplit = maxlogportL[t][0][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCG[t][0][len(ilPacket[t][0][0])-1][x-1][x-i]
                                                    for nlt in RNAsequence[y+1:j+1]:
                                                        psplit+=qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpILd:
                                                        maxlogpILd = psplit
                                    for s in range(1, d):
                                        psplit = maxlogpblockMCG[t][0][len(ilPacket[t][0][0])-1][i+s-1][s] + maxlogportLj[t][0][d-s] + Qslendist[0]
                                        if psplit > maxlogpILd:
                                            maxlogpILd = psplit
                                #IR
                                if i in lcov:
                                    maxlogpIRd = -math.inf
                                else:
                                    for s in range(0, d):
                                        psplit = maxlogportL[t][1][i+s-1][s] + maxlogpblockMCBj[t][0][len(ilPacket[t][0][0])-1][d-s] + Qslendist[0]
                                        if psplit > maxlogpIRd:
                                            maxlogpIRd = psplit
                                    psplit = maxlogportLj[t][1][d] + maxlogpblockMCBj[t][0][len(ilPacket[t][0][0])-1][0] + Qslendist[0]
                                    if psplit > maxlogpIRd:
                                        maxlogpIRd = psplit
                                    for x in range(i+1, j):
                                        if x-i < 5:
                                            for y in range(x+1, j):
                                                if searchcov(i, x-1, covlist, covpairs) == 0:
                                                    psplit = maxlogportL[t][1][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCBj[t][0][len(ilPacket[t][0][0])-1][j-y]
                                                    for nlt in RNAsequence[i:x]:
                                                        psplit += qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpIRd:
                                                        maxlogpIRd = psplit
                                    for s in range(1, min(d, 5)):
                                        if searchcov(i, i+s-1, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogportLj[t][1][d-s] + maxlogpblockMCBj[t][0][len(ilPacket[t][0][0])-1][0]
                                            for nlt in RNAsequence[i:i+s]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpIRd:
                                                maxlogpIRd = psplit
                            if ilPacket[t][0][0] != "Bulge" and ilPacket[t][0][1] != "Bulge":
                                #IL
                                psplit = maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + maxlogportLj[t][0][d]
                                if psplit > maxlogpILd:
                                    maxlogpILd = psplit
                                for s in range(1, d):
                                    psplit = maxlogportL[t][0][i+s-1][s] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][d-s] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0]
                                    if psplit > maxlogpILd:
                                        maxlogpILd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + maxlogpblockMCG[t][0][len(ilPacket[t][0][0])-1][i+s-1][s] + maxlogportLj[t][0][d-s]
                                    if psplit > maxlogpILd:
                                        maxlogpILd = psplit
                                for x in range(0, d-1):
                                    for y in range(x+1, d):
                                        psplit = maxlogpblockMCG[t][0][len(ilPacket[t][0][0])-1][i+x][x+1] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][d-y] + maxlogportL[t][0][i+y-1][y-x-1]
                                        if psplit > maxlogpILd:
                                            maxlogpILd = psplit
                                #IR
                                psplit = maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + maxlogportLj[t][1][d]
                                if psplit > maxlogpIRd:
                                    maxlogpIRd = psplit
                                for s in range(1, d):
                                    psplit = maxlogportL[t][1][i+s-1][s] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][d-s] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0]
                                    if psplit > maxlogpIRd:
                                        maxlogpIRd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + maxlogpblockMCB[t][1][len(ilReversePacket[t][0][1])-1][i+s-1][s] + maxlogportLj[t][1][d-s]
                                    if psplit > maxlogpIRd:
                                        maxlogpIRd = psplit
                                for x in range(0, d-1):
                                    for y in range(x+1, d):
                                        psplit = maxlogpblockMCB[t][1][len(ilReversePacket[t][0][1])-1][i+x][x+1] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][d-y] + maxlogportL[t][1][i+y-1][y-x-1]
                                        if psplit > maxlogpIRd:
                                            maxlogpIRd = psplit
                            maxlogpilMotifILRj[t][0].append(maxlogpILd)
                            maxlogpilMotifILRj[t][1].append(maxlogpIRd)                
                        #ILOLR
                        for t in range(0, M):
                            maxlogpOLd = -math.inf
                            maxlogpORd = -math.inf
                            if len(ilPacket[t][1][0]) == 0:
                                maxlogpOLd = maxlogpLj[d]
                                maxlogpORd = maxlogpLj[d]
                            else:
                                L = len(ilPacket[t][1][0])
                                if stemcov(RNAsequence, i, j, L, covpairs, ilPacket[t][1][1], ilPacket[t][1][0]) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        maxlogpOLd = Kbox[t][stemcode]+maxlogpL[j-L][d-2*L]
                                if stemcov(RNAsequence, i, j, L, covpairs, ReverseString(ilPacket[t][1][0]), ReverseString(ilPacket[t][1][0])) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        maxlogpORd = Kbox[t][ReverseString(stemcode)]+maxlogpL[j-L][d-2*L]
                            maxlogpilMotifOLRj[t][0].append(maxlogpOLd)
                            maxlogpilMotifOLRj[t][1].append(maxlogpORd)   
                        #Oriented O
                        for t in range(0, M):
                            maxlogpOLd = -math.inf
                            maxlogpORd = -math.inf
                            #OL
                            if ilPacket[t][0][0] == "Bulge" and ilPacket[t][0][1] != "Bulge":
                                #OL
                                if j in rcov:
                                    maxlogpOLd = -math.inf
                                else:
                                    for s in range(1, min(d, 5)):
                                        if searchcov(j-s+1, j, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogpilMotifOLR[t][0][j-s][d-s] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + pLeftRight[0]
                                            for nlt in RNAsequence[j-s+1:j+1]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpOLd:
                                                maxlogpOLd = psplit
                                    psplit = maxlogpilMotifOLRj[t][0][d] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + Qslendist[0] + pLeftRight[0]
                                    if psplit > maxlogpOLd:
                                        maxlogpOLd = psplit
                                    for x in range(i+1, j):
                                        for y in range(x+1, j):
                                            if j-y < 5:
                                                if searchcov(y+1, j, covlist, covpairs) == 0:
                                                    psplit = maxlogpilMotifOLR[t][0][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCG[t][1][len(ilPacket[t][0][1])-1][x-1][x-i] + pLeftRight[0]
                                                    for nlt in RNAsequence[y+1:j+1]:
                                                        psplit+=qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpOLd:
                                                        maxlogpOLd = psplit
                                    for s in range(1, d):
                                        psplit = maxlogpblockMCG[t][1][len(ilPacket[t][0][1])-1][i+s-1][s] + maxlogpilMotifOLRj[t][0][d-s] + Qslendist[0] + pLeftRight[0]
                                        if psplit > maxlogpOLd:
                                            maxlogpOLd = psplit
                                #OR
                                if i in lcov:
                                    maxlogpORd = -math.inf
                                else:
                                    for s in range(0, d):
                                        psplit = maxlogpilMotifOLR[t][1][i+s-1][s] + maxlogpblockMCBj[t][1][len(ilPacket[t][0][1])-1][d-s] + Qslendist[0] + pLeftRight[1]
                                        if psplit > maxlogpORd:
                                            maxlogpORd = psplit
                                    psplit = maxlogpilMotifOLRj[t][1][d] + maxlogpblockMCBj[t][1][len(ilPacket[t][0][1])-1][0] + Qslendist[0] + pLeftRight[1]
                                    if psplit > maxlogpORd:
                                        maxlogpORd = psplit
                                    for x in range(i+1, j):
                                        if x-i < 5:
                                            for y in range(x+1, j):
                                                if searchcov(i, x-1, covlist, covpairs) == 0:
                                                    psplit = maxlogpilMotifOLR[t][1][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCBj[t][1][len(ilPacket[t][0][1])-1][j-y] + pLeftRight[1]
                                                    for nlt in RNAsequence[i:x]:
                                                        psplit += qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpORd:
                                                        maxlogpORd = psplit
                                    for s in range(1, min(d, 5)):
                                        if searchcov(i, i+s-1, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogpilMotifOLRj[t][1][d-s] + maxlogpblockMCBj[t][1][len(ilPacket[t][0][1])-1][0] + pLeftRight[1]
                                            for nlt in RNAsequence[i:i+s]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpORd:
                                                maxlogpORd = psplit
                            if ilPacket[t][0][0] != "Bulge" and ilPacket[t][0][1] == "Bulge":
                                #OL
                                if i in lcov:
                                    maxlogpOLd = -math.inf
                                else:
                                    for s in range(0, d):
                                        psplit = maxlogpilMotifOLR[t][0][i+s-1][s] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][d-s] + Qslendist[0] + pLeftRight[0]
                                        if psplit > maxlogpOLd:
                                            maxlogpOLd = psplit
                                    psplit = maxlogpilMotifOLRj[t][0][d] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + Qslendist[0] + pLeftRight[0]
                                    if psplit > maxlogpOLd:
                                        maxlogpOLd = psplit
                                    for x in range(i+1, j):
                                        if x-i < 5:
                                            for y in range(x+1, j):
                                                if searchcov(i, x-1, covlist, covpairs) == 0:
                                                    psplit = maxlogpilMotifOLR[t][0][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][j-y] + pLeftRight[0]
                                                    for nlt in RNAsequence[i:x]:
                                                        psplit += qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpOLd:
                                                        maxlogpOLd = psplit
                                    for s in range(1, min(d, 5)):
                                        if searchcov(i, i+s-1, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogpilMotifOLRj[t][0][d-s] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + pLeftRight[0]
                                            for nlt in RNAsequence[i:i+s]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpOLd:
                                                maxlogpOLd = psplit
                                #OR
                                if j in rcov:
                                    maxlogpORd = -math.inf
                                else:
                                    for s in range(1, min(d, 5)):
                                        if searchcov(j-s+1, j, covlist, covpairs) == 0:
                                            psplit = Qslendist[s] + maxlogpilMotifOLR[t][1][j-s][d-s] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + pLeftRight[1]
                                            for nlt in RNAsequence[j-s+1:j+1]:
                                                psplit+=qsing_emissionsdict[nlt]
                                            if psplit > maxlogpORd:
                                                maxlogpORd = psplit
                                    psplit = maxlogpilMotifOLRj[t][1][d] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + Qslendist[0] + pLeftRight[1]
                                    if psplit > maxlogpORd:
                                        maxlogpORd = psplit
                                    for x in range(i+1, j):
                                        for y in range(x+1, j):
                                            if j-y < 5:
                                                if searchcov(y+1, j, covlist, covpairs) == 0:
                                                    psplit = maxlogpilMotifOLR[t][1][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCB[t][0][len(ilReversePacket[t][0][0])-1][x-1][x-i] + pLeftRight[1]
                                                    for nlt in RNAsequence[y+1:j+1]:
                                                        psplit+=qsing_emissionsdict[nlt]
                                                    if psplit > maxlogpORd:
                                                        maxlogpORd = psplit
                                    for s in range(1, d):
                                        psplit = maxlogpblockMCB[t][0][len(ilReversePacket[t][0][0])-1][i+s-1][s] + maxlogpilMotifOLRj[t][1][d-s] + Qslendist[0] + pLeftRight[1]
                                        if psplit > maxlogpORd:
                                            maxlogpORd = psplit
                            if ilPacket[t][0][0] != "Bulge" and ilPacket[t][0][1] != "Bulge":
                                #OL
                                psplit = maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + maxlogpLj[d] + pLeftRight[0]
                                if psplit > maxlogpOLd:
                                    maxlogpOLd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpL[i+s-1][s] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][d-s] + maxlogpblockMCGj[t][1][len(ilPacket[t][0][1])-1][0] + pLeftRight[0]
                                    if psplit > maxlogpOLd:
                                        maxlogpOLd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][0] + maxlogpblockMCG[t][1][len(ilPacket[t][0][1])-1][i+s-1][s] + maxlogpLj[d-s] + pLeftRight[0]
                                    if psplit > maxlogpOLd:
                                        maxlogpOLd = psplit
                                for x in range(0, d-1):
                                    for y in range(x+1, d):
                                        psplit = maxlogpblockMCG[t][1][len(ilPacket[t][0][1])-1][i+x][x+1] + maxlogpblockMCGj[t][0][len(ilPacket[t][0][0])-1][d-y] + maxlogpL[i+y-1][y-x-1] + pLeftRight[0]
                                        if psplit > maxlogpOLd:
                                            maxlogpOLd = psplit
                                #OR
                                psplit = maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0] + maxlogpLj[d] + pLeftRight[1]
                                if psplit > maxlogpORd:
                                    maxlogpORd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpL[i+s-1][s] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][d-s] + maxlogpblockMCBj[t][0][len(ilReversePacket[t][0][0])-1][0] + pLeftRight[1]
                                    if psplit > maxlogpORd:
                                        maxlogpORd = psplit
                                for s in range(1, d):
                                    psplit = maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][0] + maxlogpblockMCB[t][0][len(ilReversePacket[t][0][0])-1][i+s-1][s] + maxlogpLj[d-s] + pLeftRight[1]
                                    if psplit > maxlogpORd:
                                        maxlogpORd = psplit
                                for x in range(0, d-1):
                                    for y in range(x+1, d):
                                        psplit = maxlogpblockMCB[t][0][len(ilReversePacket[t][0][0])-1][i+x][x+1] + maxlogpblockMCBj[t][1][len(ilReversePacket[t][0][1])-1][d-y] + maxlogpL[i+y-1][y-x-1] + pLeftRight[1]
                                        if psplit > maxlogpORd:
                                            maxlogpORd = psplit
                            maxlogportOj[t][0].append(maxlogpOLd - pLeftRight[0])
                            maxlogportOj[t][1].append(maxlogpORd - pLeftRight[1])   
                        #IO
                        for t in range(0, M):
                            maxlogpId = -math.inf
                            maxlogpOd = -math.inf
                            #I
                            if len(ilPacket[t][1][0]) == 0:
                                psplit = maxlogpilMotifILRj[t][0][d] + pLeftRight[0]
                                if psplit > maxlogpId:
                                    maxlogpId = psplit
                                psplit = maxlogpilMotifILRj[t][1][d] + pLeftRight[1]
                                if psplit > maxlogpId:
                                    maxlogpId = psplit
                            else:
                                L = len(ilPacket[t][1][0])
                                if stemcov(RNAsequence, i, j, L, covpairs, ilPacket[t][1][0], ilPacket[t][1][1]) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        pstem = Kbox[t][stemcode]
                                        maxlogpId = pstem+maxlogpilMotifILR[t][0][j-L][d-2*L] + pLeftRight[0]
                                if stemcov(RNAsequence, i, j, L, covpairs, ReverseString(ilPacket[t][1][1]), ReverseString(ilPacket[t][1][0])) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        psplit = Kbox[t][ReverseString(stemcode)]+maxlogpilMotifILR[t][1][j-L][d-2*L] + pLeftRight[1]
                                        if psplit > maxlogpId:
                                            maxlogpId = psplit
                            maxlogpilMotifIOj[t][0].append(maxlogpId)
                            #O
                            if len(ilPacket[t][2][0]) == 0:
                                psplit = maxlogportOj[t][0][d] + pLeftRight[0]
                                if psplit > maxlogpOd:
                                    maxlogpOd = psplit
                                psplit = maxlogportOj[t][1][d] + pLeftRight[1]
                                if psplit > maxlogpOd:
                                    maxlogpOd = psplit
                            else:
                                L = len(ilPacket[t][2][0])
                                if stemcov(RNAsequence, i, j, L, covpairs, ilPacket[t][2][1], ilPacket[t][2][0]) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        pstem = K2box[t][stemcode]
                                        maxlogpOd = pstem+maxlogportO[t][0][j-L][d-2*L] + pLeftRight[0]
                                if stemcov(RNAsequence, i, j, L, covpairs, ReverseString(ilPacket[t][2][0]), ReverseString(ilPacket[t][2][1])) == 1:
                                    if d > 2*L:
                                        stemcode = ''
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        psplit = K2box[t][ReverseString(stemcode)]+maxlogportO[t][1][j-L][d-2*L] + pLeftRight[1]
                                        if psplit > maxlogpOd:
                                            maxlogpOd = psplit
                            maxlogpilMotifIOj[t][1].append(maxlogpOd)
                        #Internal Loop Motifs
                        for t in range(0, M):
                            maxlogpild = -math.inf
                            psplit = maxlogpilMotifIOj[t][0][d] + pInOut[0]
                            if psplit > maxlogpild:
                                maxlogpild = psplit
                            psplit = maxlogpilMotifIOj[t][1][d] + pInOut[1]
                            if psplit > maxlogpild:
                                maxlogpild = psplit
                            maxlogpilloopMotifsj[t].append(maxlogpild)                                 
                        #HL2
                        if i in lcov:
                            maxlogpGNRAd = -math.inf
                        else:
                            psplit = maxlogpHL2j[d-1] + n_emissionsdict[RNAsequence[i]] + pHL2[0]
                            if psplit > maxlogpHL2d:
                                maxlogpHL2d = psplit
                        maxlogpHL2j.append(maxlogpHL2d)
                        #Motifs
                        for t in range(0, N):
                            if len(hpPacket[t][1][0]) > 0:
                                maxlogpMotifd = -math.inf
                                L = len(hpPacket[t][1][0])
                                if stemcov(RNAsequence, i, j, L, covpairs, hpPacket[t][1][0], hpPacket[t][1][1]) == 1:
                                    if d >= 2*L:
                                        stemcode = ''
                                        for w in range(0, L):
                                            stemcode+=RNAsequence[i+w]
                                        for w in range(L-1, -1, -1):
                                            stemcode+=RNAsequence[j-w]
                                        pstem = Mbox[t][stemcode]
                                        psplit = maxlogpcontigMCj[t][len(hpPacket[t][0])-1][0] + maxlogpHL2[j-L][d-2*L]
                                        if psplit > maxlogpMotifd:
                                            maxlogpMotifd = psplit
                                        if d-2*L > 1:
                                            for s in range(0, d-2*L-1):
                                                psplit = maxlogpcontigMC[t][len(hpPacket[t][0])-1][i+L+s][s+1] + maxlogpHL2[j-L][d-2*L-s-1]
                                                if psplit > maxlogpMotifd:
                                                    maxlogpMotifd = psplit
                                            psplit = maxlogpcontigMC[t][len(hpPacket[t][0])-1][j-L][d-2*L] + maxlogpHL2j[0] 
                                        if psplit > maxlogpMotifd:
                                            maxlogpMotifd = psplit
                                        maxlogpMotifd = maxlogpMotifd + pstem
                                maxlogphploopMotifsj[t].append(maxlogpMotifd)
                            else:
                                maxlogpMotifd = -math.inf
                                psplit = maxlogpcontigMCj[t][len(hpPacket[t][0])-1][0] + maxlogpHL2d
                                if psplit > maxlogpMotifd:
                                    maxlogpMotifd = psplit
                                for s in range(0, d-1):
                                    psplit = maxlogpcontigMC[t][len(hpPacket[t][0])-1][i+s][s+1] + maxlogpHL2j[d-s-1] 
                                    if psplit > maxlogpMotifd:
                                        maxlogpMotifd = psplit
                                psplit = maxlogpcontigMCj[t][len(hpPacket[t][0])-1][d] + maxlogpHL2j[0] 
                                if psplit > maxlogpMotifd:
                                    maxlogpMotifd = psplit
                                maxlogphploopMotifsj[t].append(maxlogpMotifd)
                        #HL
                        if d < 33:
                            if searchcov(i, j, covlist, covpairs) == 0:
                                psplit = pHL[0] + HLlendist[d-1]
                                for nlt in RNAsequence[i:j+1]:
                                    psplit += hlsing_emissionsdict[nlt]
                                if psplit > maxlogpHLd:
                                    maxlogpHLd = psplit
                        totset = []
                        for t in range(0, N):
                            totset.append(maxlogphploopMotifsj[t][d] + pHL[t+1])
                        psplit = max(totset)
                        if psplit > maxlogpHLd:
                            maxlogpHLd = psplit                       
                        maxlogpHLj.append(maxlogpHLd)
                        #P
                        for s in range(0, d-1):
                            if s+1 < 31:
                                if searchcov(i, i+s, covlist, covpairs) == 0:
                                    psplit = maxlogpLj[d-s-1] + pP[0] + Pbulgedist[s+1-1]
                                    for nlt in RNAsequence[i:i+s+1]:
                                        psplit += bulgesing_emissionsdict[nlt]
                                    if psplit > maxlogpPd:
                                        maxlogpPd = psplit
                        for s in range(0, d-1):
                            if d-s-1 < 31:
                                if searchcov(i+s+1, j, covlist, covpairs) == 0:
                                    psplit = maxlogpL[i+s][s+1] + pP[1] + Pbulgedist[d-s-1-1]
                                    for nlt in RNAsequence[i+s+1:j+1]:
                                        psplit += bulgesing_emissionsdict[nlt]
                                    if psplit > maxlogpPd:
                                        maxlogpPd = psplit
                        if d == 2:
                            pass
                        else:
                            for x in range(i+1, j):
                                for y in range(x+1, j):
                                    if x-i < 31 and j-y < 31:
                                        if searchcov(i, x-1, covlist, covpairs) == 0 and searchcov(y+1, j, covlist, covpairs) == 0:
                                            psplit = maxlogpL[y][y-x+1] + pP[2] + Pintloopdist[x-i-1][j-y-1]
                                            for nlt in RNAsequence[i:x]:
                                                psplit += intloopsing_emissionsdict[nlt]
                                            for nlt in RNAsequence[y+1:j+1]:
                                                psplit += intloopsing_emissionsdict[nlt]
                                            if psplit > maxlogpPd:
                                                maxlogpPd = psplit
                        psplit = maxlogpHLj[d] + pP[3]
                        if psplit > maxlogpPd:
                            maxlogpPd = psplit
                        for s in range(0, d-1):
                            psplit = maxlogpM1[i+s][s+1] + maxlogpMj[d-s-1] + pP[4]
                            if psplit > maxlogpPd:
                                maxlogpPd = psplit
                        totset = []
                        for t in range(0, M):
                            totset.append(maxlogpilloopMotifsj[t][d] + pP[t+5])
                        psplit = max(totset)
                        if psplit > maxlogpPd:
                            maxlogpPd = psplit 
                        maxlogpPj.append(maxlogpPd)
            maxlogpS.append(maxlogpSj)
            maxlogpL.append(maxlogpLj)
            maxlogpF.append(maxlogpFj)
            maxlogpP.append(maxlogpPj)
            maxlogpHL.append(maxlogpHLj)
            maxlogpHL2.append(maxlogpHL2j)
            maxlogpM.append(maxlogpMj)
            maxlogpR.append(maxlogpRj)
            maxlogpM1.append(maxlogpM1j)
            for t in range(0, N):
                maxlogphploopMotifs[t].append(maxlogphploopMotifsj[t])
            for let in letter_set:
                maxlogpinsertMC[let].append(maxlogpinsertMCj[let])
            for t in range(0, N):
                for g in range(0, len(hpPacket[t][0])):
                    maxlogpcontigMC[t][g].append(maxlogpcontigMCj[t][g])
            for t in range(0, M):
                maxlogpilloopMotifs[t].append(maxlogpilloopMotifsj[t])
            for let in illetter_set:
                maxlogpinsertMCIL[let].append(maxlogpinsertMCILj[let])
            for t in range(0, M):
                maxlogpilMotifIO[t][0].append(maxlogpilMotifIOj[t][0])
                maxlogpilMotifIO[t][1].append(maxlogpilMotifIOj[t][1])
            for t in range(0, M):
                maxlogpilMotifOLR[t][0].append(maxlogpilMotifOLRj[t][0])
                maxlogpilMotifOLR[t][1].append(maxlogpilMotifOLRj[t][1])
            for t in range(0, M):
                maxlogpilMotifILR[t][0].append(maxlogpilMotifILRj[t][0])
                maxlogpilMotifILR[t][1].append(maxlogpilMotifILRj[t][1])
            for t in range(0, M):
                maxlogportL[t][0].append(maxlogportLj[t][0])
                maxlogportL[t][1].append(maxlogportLj[t][1])
            for t in range(0, M):
                maxlogportO[t][0].append(maxlogportOj[t][0])
                maxlogportO[t][1].append(maxlogportOj[t][1])
            for t in range(0, M):
                        for el in range(0, 2):
                            if ilPacket[t][0][el] != "Bulge":
                                for g in range(0, len(ilPacket[t][0][el])):
                                    maxlogpblockMCG[t][el][g].append(maxlogpblockMCGj[t][el][g])
            for t in range(0, M):
                for el in range(0, 2):
                    if ilReversePacket[t][0][el] != "Bulge":
                        for g in range(0, len(ilReversePacket[t][0][el])):
                            maxlogpblockMCB[t][el][g].append(maxlogpblockMCBj[t][el][g])
        RNAseqlist = []
        for char in RNAsequence:
            RNAseqlist.append(char)

        parse = ["S"]
        subseq = [[n-1, n]]
        rebuild = []
        reduc = []
        for q in range(0, n):
            rebuild.append("")
            reduc.append("")
        while rebuild != RNAseqlist:
            p = len(parse)
            parsenew = []
            subseqnew = []            
            for t in range(0, p):
                j = subseq[t][0]
                d = subseq[t][1]
                i = j-d+1
                #S
                if parse[t] == "S":
                    if d == 0:
                        pass
                    else:
                        if abs(maxlogpS[j][d] - (n_emissionsdict[RNAsequence[i]] + maxlogpS[j][d-1] + pS[0])) < 10e-13:
                            parsenew.append(["n", "S"])
                            subseqnew.append([[i, 1], [j, d-1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "."
                        for s in range(1, d+1):
                            if abs(maxlogpS[j][d] - (maxlogpL[i+s-1][s] + maxlogpS[j][d-s] + pS[1])) < 10e-13:
                                parsenew.append(["L", "S"])
                                subseqnew.append([[i+s-1, s], [j, d-s]])
                #L
                if parse[t] == "L":
                    if d < 2:
                        pass
                    else:
                        if abs(maxlogpL[j][d] - (pbpL1[bptonum(RNAsequence[i] + RNAsequence[j])] + maxlogpF[j-1][d-2] + pL[0])) < 10e-13:
                            parsenew.append(["bp(", "F", ")bp"])
                            subseqnew.append([[i, 1], [j-1, d-2], [j, 1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "<"
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = ">"
                        elif abs(maxlogpL[j][d] - (pbpL2[bptonum(RNAsequence[i] + RNAsequence[j])] + maxlogpP[j-1][d-2] + pL[1])) < 10e-13:
                            parsenew.append(["bp(", "P", ")bp"])
                            subseqnew.append([[i, 1], [j-1, d-2], [j, 1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "<"
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = ">"
                #F
                if parse[t] == "F":
                    if d < 2:
                        pass
                    else:
                        key2 = bptonum(RNAsequence[i-1] + RNAsequence[j+1])
                        key3 = bptonum(RNAsequence[i] + RNAsequence[j])
                        if abs(maxlogpF[j][d] - (maxlogpF[j-1][d-2] + pF[0] + stackedbpF1[key2][key3])) < 10e-13:
                            parsenew.append(["bp(", "F", ")bp"])
                            subseqnew.append([[i, 1], [j-1, d-2], [j, 1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "<"
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = ">"
                        elif abs(maxlogpF[j][d] - (maxlogpP[j-1][d-2] + pF[1] + stackedbpF2[key2][key3])) < 10e-13:
                            parsenew.append(["bp(", "P", ")bp"])
                            subseqnew.append([[i, 1], [j-1, d-2], [j, 1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "<"
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = ">"
                #HL2
                if parse[t] == "HL2":
                    if d == 0:
                        pass
                    else:
                        parsenew.append(["n", "HL2"])
                        subseqnew.append([[i, 1], [j, d-1]])
                        rebuild[i] = RNAsequence[i]
                        reduc[i] = "."
                #Motifs
                for a in range(0, N):
                    if parse[t] == "Motif " + str(a):
                        if d == 0:
                            if len(hpPacket[a][1][0]) == 0:
                                parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                subseqnew.append([[i, d], [j, d]])
                        else:
                            if len(hpPacket[a][1][0]) == 0:
                                if abs(maxlogphploopMotifs[a][j][d] - (maxlogpcontigMC[a][len(hpPacket[a][0])-1][j][0] + maxlogpHL2[j][d])) < 10e-13:
                                    parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                    subseqnew.append([[i, 0], [j, d]])
                                for s in range(1, d+1):
                                    if abs(maxlogphploopMotifs[a][j][d] - (maxlogpcontigMC[a][len(hpPacket[a][0])-1][i+s-1][s] + maxlogpHL2[j][d-s])) < 10e-13:
                                        parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                        subseqnew.append([[i+s-1, s], [j, d-s]])
                            else:
                                L = len(hpPacket[a][1][0])
                                stemcode = ''
                                for w in range(0, L):
                                    stemcode+=RNAsequence[i+w]
                                for w in range(L-1, -1, -1):
                                    stemcode+=RNAsequence[j-w]
                                pstem = Mbox[a][stemcode]
                                if d - 2*L == 0:
                                    parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                    subseqnew.append([[i+L, d-2*L], [j-L, d-2*L]])
                                else:
                                    if abs(maxlogphploopMotifs[a][j][d] - (maxlogpcontigMC[a][len(hpPacket[a][0])-1][j][0] + maxlogpHL2[j-L][d-2*L] + pstem)) < 10e-13:
                                        parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                        subseqnew.append([[i+L, 0], [j-L, d-2*L]])
                                    for s in range(1, d-2*L+1):
                                        if abs(maxlogphploopMotifs[a][j][d] - (maxlogpcontigMC[a][len(hpPacket[a][0])-1][i+L+s-1][s] + maxlogpHL2[j-L][d-s-2*L] + pstem)) < 10e-13:
                                            parsenew.append(["Block " + str(a)+"."+str(len(hpPacket[a][0])-1), "HL2"])
                                            subseqnew.append([[i+L+s-1, s], [j-L, d-s-2*L]])
                                    for q in range(0, L):
                                        rebuild[i+q] = RNAsequence[i+q]
                                        rebuild[j-q] = RNAsequence[j-q]
                                        reduc[i+q] = "["
                                        reduc[j-q] = "]"
                #Internal Loop Motifs
                for a in range(0, M):
                    if parse[t] == "KMotif " + str(a):
                        if abs(maxlogpilloopMotifs[a][j][d] - (maxlogpilMotifIO[a][0][j][d] + pInOut[0]))<10e-13:
                            parsenew.append(["In"+str(a)])
                            subseqnew.append([[j, d]])
                        if abs(maxlogpilloopMotifs[a][j][d] - (maxlogpilMotifIO[a][1][j][d] + pInOut[1]))<10e-13:
                            parsenew.append(["Out"+str(a)])
                            subseqnew.append([[j, d]])
                #Oriented L
                for a in range(0, M):
                    if parse[t] == "LL":
                        if len(ilPacket[a][2][0]) == 0:
                            parsenew.append(["L"])
                            subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][2][0])
                            parsenew.append(["L"])
                            subseqnew.append([[j-L, d-2*L]])
                            for q in range(0, L):
                                    rebuild[i+q] = RNAsequence[i+q]
                                    rebuild[j-q] = RNAsequence[j-q]
                                    reduc[i+q] = "["
                                    reduc[j-q] = "]"
                    if parse[t] == "LR":
                        if len(ilPacket[a][2][0]) == 0:
                            parsenew.append(["L"])
                            subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][2][0])
                            parsenew.append(["L"])
                            subseqnew.append([[j-L, d-2*L]])
                            for q in range(0, L):
                                    rebuild[i+q] = RNAsequence[i+q]
                                    rebuild[j-q] = RNAsequence[j-q]
                                    reduc[i+q] = "["
                                    reduc[j-q] = "]"
                #Oriented O
                for a in range(0, M):
                    if parse[t] == "OrtOL"+str(a):
                        if ilPacket[a][0][0] == "Bulge" and ilPacket[a][0][1] != "Bulge":
                            #OL
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogpilMotifOLR[a][0][j-s][d-s] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0]
                                for nlt in RNAsequence[j-s+1:j+1]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset = ["OL"+str(a)]
                                        subseqt = [[j-s, d-s]]
                                        for k in range(j-s+1, j+1):
                                            parset.append("n")
                                            subseqt.append([k, 1])
                                        parsenew.append(parset)
                                        subseqnew.append(subseqt)
                                        for k in range(j-s+1, j+1):
                                            rebuild[k] = RNAsequence[k]
                                            reduc[k] = "."                  
                            psplit = maxlogpilMotifOLR[a][0][j][d] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0] + Qslendist[0]
                            if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["OL"+str(a)])
                                subseqnew.append([[j, d]])                       
                            for x in range(i+1, j):
                                for y in range(x+1, j):
                                    if j-y < 5:
                                        psplit = maxlogpilMotifOLR[a][0][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][x-1][x-i]
                                        for nlt in RNAsequence[y+1:j+1]:
                                            psplit+=qsing_emissionsdict[nlt]
                                        if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                            parset = ["GBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "OL"+str(a)]
                                            subseqt = [[x-1, x-i], [y, y-x+1]]
                                            for k in range(y+1, j+1):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(y+1, j+1):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "." 
                            for s in range(1, d):
                                psplit = maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][i+s-1][s] + maxlogpilMotifOLR[a][0][j][d-s] + Qslendist[0]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["GBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "OL"+str(a)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] == "Bulge":
                            #OL
                            for s in range(0, d):
                                psplit = maxlogpilMotifOLR[a][0][i+s-1][s] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][d-s] + Qslendist[0]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["OL"+str(a), "GBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            psplit = maxlogpilMotifOLR[a][0][j][d] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0] + Qslendist[0]
                            if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["OL"+str(a)])
                                subseqnew.append([[j, d]])
                            for x in range(i+1, j):
                                if x-i < 5:
                                    for y in range(x+1, j):
                                        psplit = maxlogpilMotifOLR[a][0][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][j-y]
                                        for nlt in RNAsequence[i:x]:
                                            psplit += qsing_emissionsdict[nlt]
                                        if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                            parset = []
                                            subseqt = []
                                            for k in range(i, x):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parset.append("OL"+str(a))
                                            subseqt.append([y, y-x+1])
                                            parset.append("GBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1))
                                            subseqt.append([j, j-y])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(i, x):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "."
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogpilMotifOLR[a][0][j][d-s] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0]
                                for nlt in RNAsequence[i:i+s]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset.append("n")
                                        subseqt.append([i+k, 1])
                                    parset.append("OL"+str(a))
                                    subseqt.append([j, d-s])
                                    parsenew.append(parset)
                                    subseqnew.append(subseqt)
                                    for k in range(0, s):
                                        rebuild[i+k] = RNAsequence[i+k]
                                        reduc[i+k] = "."
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] != "Bulge":
                            #OL
                            psplit = maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0] + maxlogpL[j][d]
                            if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["OL"+str(a)])
                                subseqnew.append([[j, d]])
                            for s in range(1, d):
                                psplit = maxlogpL[i+s-1][s] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][d-s] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["OL"+str(a), "GBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for s in range(1, d):
                                psplit = maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][i+s-1][s] + maxlogpL[j][d-s]
                                if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["GBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "OL"+str(a)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for x in range(0, d-1):
                                for y in range(x+1, d):
                                    psplit = maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][i+x][x+1] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][d-y] + maxlogpL[i+y-1][y-x-1]
                                    if abs(maxlogportO[a][0][j][d] - psplit) < 10e-13:
                                        parsenew.append(["GBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "OL"+str(a), "GBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                        subseqnew.append([[i+x, x+1], [i+y-1, y-x-1], [j, d-y]])
                    if parse[t] == "OrtOR"+str(a):
                        if ilPacket[a][0][0] == "Bulge" and ilPacket[a][0][1] != "Bulge":
                            #OR
                            for s in range(0, d):
                                psplit = maxlogpilMotifOLR[a][1][i+s-1][s] + maxlogpblockMCB[a][1][len(ilPacket[a][0][1])-1][j][d-s] + Qslendist[0]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["OR"+str(a), "BBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            psplit = maxlogpilMotifOLR[a][1][j][d] + maxlogpblockMCB[a][1][len(ilPacket[a][0][1])-1][j][0] + Qslendist[0]
                            if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["OR"+str(a)])
                                subseqnew.append([[j, d]])
                            for x in range(i+1, j):
                                if x-i < 5:
                                    for y in range(x+1, j):
                                        psplit = maxlogpilMotifOLR[a][1][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCB[a][1][len(ilPacket[a][0][1])-1][j][j-y]
                                        for nlt in RNAsequence[i:x]:
                                            psplit += qsing_emissionsdict[nlt]
                                        if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                            parset = []
                                            subseqt = []
                                            for k in range(i, x):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parset.append("OR"+str(a))
                                            subseqt.append([y, y-x+1])
                                            parset.append("BBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1))
                                            subseqt.append([j, j-y])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(i, x):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "."
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogpilMotifOLR[a][1][j][d-s] + maxlogpblockMCB[a][1][len(ilPacket[a][0][1])-1][j][0]
                                for nlt in RNAsequence[i:i+s]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset.append("n")
                                        subseqt.append([i+k, 1])
                                    parset.append("OR"+str(a))
                                    subseqt.append([j, d-s])
                                    parsenew.append(parset)
                                    subseqnew.append(subseqt)
                                    for k in range(0, s):
                                        rebuild[i+k] = RNAsequence[i+k]
                                        reduc[i+k] = "."                 
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] == "Bulge":
                            #OR
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogpilMotifOLR[a][1][j-s][d-s] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0]
                                for nlt in RNAsequence[j-s+1:j+1]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset = ["OR"+str(a)]
                                        subseqt = [[j-s, d-s]]
                                        for k in range(j-s+1, j+1):
                                            parset.append("n")
                                            subseqt.append([k, 1])
                                        parsenew.append(parset)
                                        subseqnew.append(subseqt)
                                        for k in range(j-s+1, j+1):
                                            rebuild[k] = RNAsequence[k]
                                            reduc[k] = "."
                            psplit = maxlogpilMotifOLR[a][1][j][d] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0] + Qslendist[0]
                            if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["OR"+str(a)])
                                subseqnew.append([[j, d]])                            
                            for x in range(i+1, j):
                                for y in range(x+1, j):
                                    if j-y < 5:
                                        psplit = maxlogpilMotifOLR[a][1][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][x-1][x-i]
                                        for nlt in RNAsequence[y+1:j+1]:
                                            psplit+=qsing_emissionsdict[nlt]
                                        if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                            parset = ["BBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "OR"+str(a)]
                                            subseqt = [[x-1, x-i], [y, y-x+1]]
                                            for k in range(y+1, j+1):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(y+1, j+1):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "." 
                            for s in range(1, d):
                                psplit = maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][i+s-1][s] + maxlogpilMotifOLR[a][1][j][d-s] + Qslendist[0]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["BBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "OR"+str(a)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] != "Bulge":
                            #OR
                            psplit = maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0] + maxlogpL[j][d]
                            if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["OR"+str(a)])
                                subseqnew.append([[j, d]])
                            for s in range(1, d):
                                psplit = maxlogpL[i+s-1][s] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][d-s] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["OR"+str(a), "BBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])                                
                            for s in range(1, d):
                                psplit = maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][i+s-1][s] + maxlogpL[j][d-s]
                                if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["BBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "OR"+str(a)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])                                
                            for x in range(0, d-1):
                                for y in range(x+1, d):
                                    psplit = maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][i+x][x+1] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][d-y] + maxlogpL[i+y-1][y-x-1]
                                    if abs(maxlogportO[a][1][j][d] - psplit) < 10e-13:
                                        parsenew.append(["BBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "OR"+str(a), "BBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                        subseqnew.append([[i+x, x+1], [i+y-1, y-x-1], [j, d-y]])
                #Internal IO
                for a in range(0, M):
                    #I
                    if parse[t] == "In"+str(a):
                        if len(ilPacket[a][1][0]) == 0:
                            if abs(maxlogpilMotifIO[a][0][j][d] - (maxlogpilMotifILR[a][0][j][d] + pLeftRight[0])) < 10e-13:
                                parsenew.append(["IL"+str(a)])
                                subseqnew.append([[j, d]])
                            if abs(maxlogpilMotifIO[a][0][j][d] - (maxlogpilMotifILR[a][1][j][d] + pLeftRight[1])) < 10e-13:
                                parsenew.append(["IR"+str(a)])
                                subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][1][0])
                            stemcode = ''
                            for w in range(0, L):
                                stemcode+=RNAsequence[i+w]
                            for w in range(L-1, -1, -1):
                                stemcode+=RNAsequence[j-w]
                            pstem = Kbox[a][stemcode]
                            if abs(maxlogpilMotifIO[a][0][j][d] - (pstem + maxlogpilMotifILR[a][0][j-L][d-2*L] + pLeftRight[0])) < 10e-13:
                                parsenew.append(["IL"+str(a)])
                                subseqnew.append([[j-L, d-2*L]])
                                for q in range(0, L):
                                        rebuild[i+q] = RNAsequence[i+q]
                                        rebuild[j-q] = RNAsequence[j-q]
                                        reduc[i+q] = "["
                                        reduc[j-q] = "]"
                            pstem2 = Kbox[a][ReverseString(stemcode)]
                            if abs(maxlogpilMotifIO[a][0][j][d] - (pstem2 + maxlogpilMotifILR[a][1][j-L][d-2*L] + pLeftRight[1])) < 10e-13:
                                parsenew.append(["IR"+str(a)])
                                subseqnew.append([[j-L, d-2*L]])
                                for q in range(0, L):
                                        rebuild[i+q] = RNAsequence[i+q]
                                        rebuild[j-q] = RNAsequence[j-q]
                                        reduc[i+q] = "["
                                        reduc[j-q] = "]"
                    #O
                    if parse[t] == "Out"+str(a):
                        if len(ilPacket[a][2][0]) == 0:
                            if abs(maxlogpilMotifIO[a][1][j][d] - (maxlogportO[a][0][j][d] + pLeftRight[0])) < 10e-13:
                                parsenew.append(["OrtOL"+str(a)])
                                subseqnew.append([[j, d]])
                            if abs(maxlogpilMotifIO[a][1][j][d] - (maxlogportO[a][1][j][d] + pLeftRight[1])) < 10e-13:
                                parsenew.append(["OrtOR"+str(a)])
                                subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][2][0])
                            stemcode = ''
                            for w in range(L-1, -1, -1):
                                stemcode+=RNAsequence[j-w]
                            for w in range(0, L):
                                stemcode+=RNAsequence[i+w]
                            pstem = K2box[a][stemcode]
                            if abs(maxlogpilMotifIO[a][1][j][d] - (pstem + maxlogportO[a][0][j-L][d-2*L] + pLeftRight[0])) < 10e-13:
                                parsenew.append(["OrtOL"+str(a)])
                                subseqnew.append([[j-L, d-2*L]])
                                for q in range(0, L):
                                        rebuild[i+q] = RNAsequence[i+q]
                                        rebuild[j-q] = RNAsequence[j-q]
                                        reduc[i+q] = "["
                                        reduc[j-q] = "]"
                            pstem2 = K2box[a][ReverseString(stemcode)]
                            if abs(maxlogpilMotifIO[a][1][j][d] - (pstem2 + maxlogportO[a][1][j-L][d-2*L] + pLeftRight[1])) < 10e-13:
                                parsenew.append(["OrtOR"+str(a)])
                                subseqnew.append([[j-L, d-2*L]])
                                for q in range(0, L):
                                        rebuild[i+q] = RNAsequence[i+q]
                                        rebuild[j-q] = RNAsequence[j-q]
                                        reduc[i+q] = "["
                                        reduc[j-q] = "]"            
                #Internal Loop OLR
                for a in range(0, M):
                    if parse[t] == "OL"+str(a):
                        if len(ilPacket[a][1][0]) == 0:
                            parsenew.append(["L"])
                            subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][1][0])
                            parsenew.append(["L"])
                            subseqnew.append([[j-L, d-2*L]])
                            for q in range(0, L):
                                    rebuild[i+q] = RNAsequence[i+q]
                                    rebuild[j-q] = RNAsequence[j-q]
                                    reduc[i+q] = "["
                                    reduc[j-q] = "]"
                    if parse[t] == "OR"+str(a):
                        if len(ilPacket[a][1][0]) == 0:
                            parsenew.append(["L"])
                            subseqnew.append([[j, d]])
                        else:
                            L = len(ilPacket[a][1][0])
                            parsenew.append(["L"])
                            subseqnew.append([[j-L, d-2*L]])
                            for q in range(0, L):
                                    rebuild[i+q] = RNAsequence[i+q]
                                    rebuild[j-q] = RNAsequence[j-q]
                                    reduc[i+q] = "["
                                    reduc[j-q] = "]"
                
                
                #Internal Loop ILR
                for a in range(0, M):
                    #IL
                    if parse[t] == "IL"+str(a):
                        if ilPacket[a][0][0] == "Bulge" and ilPacket[a][0][1] != "Bulge":
                            for s in range(0, d):
                                psplit = maxlogportL[a][0][i+s-1][s] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][d-s] + Qslendist[0]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["LL", "GBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])      
                            psplit = maxlogportL[a][0][j][d] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0] + Qslendist[0]
                            if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["LL"])
                                subseqnew.append([[j, d]])                            
                            for x in range(i+1, j):
                                if x-i < 5:
                                    for y in range(x+1, j):
                                        psplit = maxlogportL[a][0][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][j-y]
                                        for nlt in RNAsequence[i:x]:
                                            psplit += qsing_emissionsdict[nlt]
                                        if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                            parset = []
                                            subseqt = []
                                            for k in range(i, x):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parset.append("LL")
                                            subseqt.append([y, y-x+1])
                                            parset.append("GBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1))
                                            subseqt.append([j, j-y])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(i, x):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "."
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogportL[a][0][j][d-s] + maxlogpblockMCG[j][a][1][len(ilPacket[a][0][1])-1][0]
                                for nlt in RNAsequence[i:i+s]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset.append("n")
                                        subseqt.append([i+k, 1])
                                    parset.append("LL")
                                    subseqt.append([j, d-s])
                                    parsenew.append(parset)
                                    subseqnew.append(subseqt)
                                    for k in range(0, s):
                                        rebuild[i+k] = RNAsequence[i+k]
                                        reduc[i+k] = "."
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] == "Bulge":
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogportL[a][0][j-s][d-s] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0]
                                for nlt in RNAsequence[j-s+1:j+1]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset = ["LL"]
                                        subseqt = [[j-s, d-s]]
                                        for k in range(j-s+1, j+1):
                                            parset.append("n")
                                            subseqt.append([k, 1])
                                        parsenew.append(parset)
                                        subseqnew.append(subseqt)
                                        for k in range(j-s+1, j+1):
                                            rebuild[k] = RNAsequence[k]
                                            reduc[k] = "."                                  
                            psplit = maxlogportL[a][0][j][d] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0] + Qslendist[0]
                            if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["LL"])
                                subseqnew.append([[j, d]])
                            for x in range(i+1, j):
                                for y in range(x+1, j):
                                    if j-y < 5:
                                        psplit = maxlogportL[a][0][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][x-1][x-i]
                                        for nlt in RNAsequence[y+1:j+1]:
                                            psplit+=qsing_emissionsdict[nlt]
                                        if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                            parset = ["GBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "LL"]
                                            subseqt = [[x-1, x-i], [y, y-x+1]]
                                            for k in range(y+1, j+1):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(y+1, j+1):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "."                                           
                            for s in range(1, d):
                                psplit = maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][i+s-1][s] + maxlogportL[a][0][j][d-s] + Qslendist[0]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["GBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "LL"])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] != "Bulge":
                            psplit = maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0] + maxlogportL[a][0][j][d]
                            if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                parsenew.append(["LL"])
                                subseqnew.append([[j, d]])
                            for s in range(1, d):
                                psplit = maxlogportL[a][0][i+s-1][s] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][d-s] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][j][0]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["LL", "GBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for s in range(1, d):
                                psplit = maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][0] + maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][i+s-1][s] + maxlogportL[a][0][j][d-s]
                                if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                    parsenew.append(["GBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "LL"])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for x in range(0, d-1):
                                for y in range(x+1, d):
                                    psplit = maxlogpblockMCG[a][0][len(ilPacket[a][0][0])-1][i+x][x+1] + maxlogpblockMCG[a][1][len(ilPacket[a][0][1])-1][j][d-y] + maxlogportL[a][0][i+y-1][y-x-1]
                                    if abs(maxlogpilMotifILR[a][0][j][d] - psplit) < 10e-13:
                                        parsenew.append(["GBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1), "LL", "GBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1)])
                                        subseqnew.append([[i+x, x+1], [i+y-1, y-x-1], [j, d-y]])
                    #IR
                    if parse[t] == "IR"+str(a):
                        if ilPacket[a][0][0] == "Bulge" and ilPacket[a][0][1] != "Bulge":
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogportL[a][1][j-s][d-s] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0]
                                for nlt in RNAsequence[j-s+1:j+1]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset = ["LR"]
                                        subseqt = [[j-s, d-s]]
                                        for k in range(j-s+1, j+1):
                                            parset.append("n")
                                            subseqt.append([k, 1])
                                        parsenew.append(parset)
                                        subseqnew.append(subseqt)
                                        for k in range(j-s+1, j+1):
                                            rebuild[k] = RNAsequence[k]
                                            reduc[k] = "."   
                            psplit = maxlogportL[a][1][j][d] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0] + Qslendist[0]
                            if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["LR"])
                                subseqnew.append([[j, d]])
                            for x in range(i+1, j):
                                for y in range(x+1, j):
                                    if j-y < 5:
                                        psplit = maxlogportL[a][1][y][y-x+1] + Qslendist[j-y] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][x-1][x-i]
                                        for nlt in RNAsequence[y+1:j+1]:
                                            psplit+=qsing_emissionsdict[nlt]
                                        if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:   
                                            parset = ["BBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "LR"]
                                            subseqt = [[x-1, x-i], [y, y-x+1]]
                                            for k in range(y+1, j+1):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(y+1, j+1):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "." 
                            for s in range(1, d):
                                psplit = maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][i+s-1][s] + maxlogportL[a][1][j][d-s] + Qslendist[0]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["BBlock " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "LR"])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] == "Bulge":
                            for s in range(0, d):
                                psplit = maxlogportL[a][1][i+s-1][s] + maxlogpblockMCB[a][0][len(ilPacket[a][0][0])-1][j][d-s] + Qslendist[0]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["LR", "BBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            psplit = maxlogportL[a][1][j][d] + maxlogpblockMCB[a][0][len(ilPacket[a][0][0])-1][j][0] + Qslendist[0]
                            if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["LR"])
                                subseqnew.append([[j, d]])
                            for x in range(i+1, j):
                                if x-i < 5:
                                    for y in range(x+1, j):
                                        psplit = maxlogportL[a][1][y][y-x+1] + Qslendist[x-i] + maxlogpblockMCB[a][0][len(ilPacket[a][0][0])-1][j][j-y]
                                        for nlt in RNAsequence[i:x]:
                                            psplit += qsing_emissionsdict[nlt]
                                        if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                            parset = []
                                            subseqt = []
                                            for k in range(i, x):
                                                parset.append("n")
                                                subseqt.append([k, 1])
                                            parset.append("LR")
                                            subseqt.append([y, y-x+1])
                                            parset.append("BBlock " + str(a)+"."+str(len(ilPacket[a][0][0])-1))
                                            subseqt.append([j, j-y])
                                            parsenew.append(parset)
                                            subseqnew.append(subseqt)
                                            for k in range(i, x):
                                                rebuild[k] = RNAsequence[k]
                                                reduc[k] = "."
                            for s in range(1, min(d, 5)):
                                psplit = Qslendist[s] + maxlogportL[a][1][j][d-s] + maxlogpblockMCB[a][0][len(ilPacket[a][0][0])-1][j][0]
                                for nlt in RNAsequence[i:i+s]:
                                    psplit+=qsing_emissionsdict[nlt]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parset = []
                                    subseqt = []
                                    for k in range(0, s):
                                        parset.append("n")
                                        subseqt.append([i+k, 1])
                                    parset.append("LR")
                                    subseqt.append([j, d-s])
                                    parsenew.append(parset)
                                    subseqnew.append(subseqt)
                                    for k in range(0, s):
                                        rebuild[i+k] = RNAsequence[i+k]
                                        reduc[i+k] = "."
                        if ilPacket[a][0][0] != "Bulge" and ilPacket[a][0][1] != "Bulge":
                            psplit = maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0] + maxlogportL[a][1][j][d]
                            if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                parsenew.append(["LR"])
                                subseqnew.append([[j, d]])
                            for s in range(1, d):
                                psplit = maxlogportL[a][1][i+s-1][s] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][d-s] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][j][0]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["LR", "BBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for s in range(1, d):
                                psplit = maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][0] + maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][i+s-1][s] + maxlogportL[a][1][j][d-s]
                                if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                    parsenew.append(["BBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "LR"])
                                    subseqnew.append([[i+s-1, s], [j, d-s]])
                            for x in range(0, d-1):
                                for y in range(x+1, d):
                                    psplit = maxlogpblockMCB[a][1][len(ilReversePacket[a][0][1])-1][i+x][x+1] + maxlogpblockMCB[a][0][len(ilReversePacket[a][0][0])-1][j][d-y] + maxlogportL[a][1][i+y-1][y-x-1]
                                    if abs(maxlogpilMotifILR[a][1][j][d] - psplit) < 10e-13:
                                        parsenew.append(["BBlock2 " + str(a)+"."+str(len(ilPacket[a][0][1])-1), "LR", "BBlock1 " + str(a)+"."+str(len(ilPacket[a][0][0])-1)])
                                        subseqnew.append([[i+x, x+1], [i+y-1, y-x-1], [j, d-y]])                               
                                                
                #Internal Loop Blocks
                for a in range(0, M):
                    for el in range(0, 2):
                        if ilPacket[a][0][el] != "Bulge":
                            for g in range(0, len(ilPacket[a][0][el])):
                                if parse[t] == "GBlock " + str(a) + "." + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilPacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["GBlock " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilPacket[a][0][el][-1-g].lower(), "GBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "GBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCG[a][el][g][j][d] - (letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilPacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCG[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilPacket[a][0][el][-1-g], "GBlock " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                                if parse[t] == "GBlock1 " + str(a) + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilPacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["GBlock1 " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilPacket[a][0][el][-1-g].lower(), "GBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "GBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCG[a][el][g][j][d] - (letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilPacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCG[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilPacket[a][0][el][-1-g], "GBlock1 " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                                if parse[t] == "GBlock2 " + str(a) + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilPacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["GBlock2 " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilPacket[a][0][el][-1-g].lower(), "GBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d-1] + letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "GBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCG[a][el][g][j][d] - (maxlogpblockMCG[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["GBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCG[a][el][g][j][d] - (letter_emissionsdict[ilPacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilPacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCG[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilPacket[a][0][el][-1-g], "GBlock2 " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                                if parse[t] == "BBlock " + str(a) + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilReversePacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["BBlock " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilReversePacket[a][0][el][-1-g].lower(), "BBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "BBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCB[a][el][g][j][d] - (letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilReversePacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCB[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilReversePacket[a][0][el][-1-g], "BBlock " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                                if parse[t] == "BBlock1 " + str(a) + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilReversePacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["BBlock1 " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilReversePacket[a][0][el][-1-g].lower(), "BBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "BBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock1 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCB[a][el][g][j][d] - (letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilReversePacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCB[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilReversePacket[a][0][el][-1-g], "BBlock1 " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                                if parse[t] == "BBlock2 " + str(a) + str(g):
                                    if g == 0:
                                        if d == 0:
                                            pass
                                        if d == 1:
                                            parsenew.append([ilReversePacket[a][0][el][-1].lower()])
                                            subseqnew.append([[j, d]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"
                                    else:
                                        if d == 0:
                                            parsenew.append(["BBlock2 " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[j, d]])
                                        elif d == 1:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append([ilReversePacket[a][0][el][-1-g].lower(), "BBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])

                                        else:
                                            if abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d-1] + letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                                parsenew.append(["n", "BBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[i, 1], [j, d-1]])
                                                rebuild[i] = RNAsequence[i]
                                                reduc[i] = "x"
                                            elif abs(maxlogpblockMCB[a][el][g][j][d] - (maxlogpblockMCB[a][el][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                                parsenew.append(["BBlock2 " + str(a)+"."+str(g-1)])
                                                subseqnew.append([[j, d]])
                                            for s in range(1, d):
                                                if abs(maxlogpblockMCB[a][el][g][j][d] - (letter_emissionsdict[ilReversePacket[a][0][el][-1-g]][RNAsequence[i]] + maxlogpinsertMCIL[ilReversePacket[a][0][el][-1-g]][i+s][s] + maxlogpblockMCB[a][el][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                                    parsenew.append(["n", "ILI"+ilReversePacket[a][0][el][-1-g], "BBlock2 " + str(a)+"."+str(g-1)])
                                                    subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                                    rebuild[i] = RNAsequence[i]
                                                    reduc[i] = "x"
                #HL
                if parse[t] == "HL":
                    if 0 < d < 33:
                        psplit = pHL[0] + HLlendist[d-1]
                        for nlt in RNAsequence[i:j+1]:
                            psplit += hlsing_emissionsdict[nlt]
                        if abs(maxlogpHL[j][d] - psplit) < 10e-13:
                            prlt = ["n"]
                            subseqlt = [[i, 1]]
                            for s in range(t+1, t+d):
                                prlt.append("n")
                                subseqlt.append([s-t+i, 1])                   
                            for s in range(i, j+1):
                                rebuild[s] = RNAsequence[s]
                                reduc[s] = "."
                            parsenew.append(prlt)
                            subseqnew.append(subseqlt)
                    for a in range(0, N):
                        if abs(maxlogpHL[j][d] - (maxlogphploopMotifs[a][j][d] + pHL[a+1])) < 10e-13:
                            parsenew.append(["Motif " + str(a)])
                            subseqnew.append([[j, d]])                
                #P
                if parse[t] == "P":
                    if d == 2:
                        if abs(maxlogpP[j][d] - (maxlogpM1[i][1] + maxlogpM[j][1] + pP[4])) < 10e-13:
                            parsenew.append(["M1", "M"])
                            subseqnew.append([[i, 1], [j, 1]])
                    else:
                        for x in range(i+1, j):
                            for y in range(x+1, j):
                                if x-i < 31 and j-y < 31:
                                    psplit = maxlogpL[y][y-x+1] + pP[2] + Pintloopdist[x-i-1][j-y-1]
                                    for nlt in RNAsequence[i:x]:
                                        psplit += intloopsing_emissionsdict[nlt]
                                    for nlt in RNAsequence[y+1:j+1]:
                                        psplit += intloopsing_emissionsdict[nlt]
                                    if abs(maxlogpP[j][d] - psplit) < 10e-13:
                                        prlt = ["L"]
                                        subseqlt = []
                                        for v in range(i, x):
                                            prlt.insert(0, "n")
                                            subseqlt.append([v, 1])
                                            rebuild[v] = RNAsequence[v]
                                            reduc[v] = "."
                                        subseqlt.append([y, y-x+1])
                                        for w in range(y+1, j+1):
                                            prlt.append("n")
                                            subseqlt.append([w, 1])
                                            rebuild[w] = RNAsequence[w]
                                            reduc[w] = "."
                                        parsenew.append(prlt)
                                        subseqnew.append(subseqlt)
                    for s in range(0, d-1):
                        if s+1 < 31:
                            psplit = maxlogpL[j][d-s-1] + pP[0] + Pbulgedist[s+1-1]
                            for nlt in RNAsequence[i:i+s+1]:
                                psplit += bulgesing_emissionsdict[nlt]
                            if abs(maxlogpP[j][d] - psplit) < 10e-13:
                                prlt = ["L"]
                                subseqlt = []
                                for u in range(0, s+1):
                                    prlt.insert(0, "n")
                                    subseqlt.append([i+u, 1])
                                    rebuild[i+u] = RNAsequence[i+u]
                                    reduc[i+u] = "."
                                subseqlt.append([j, d-s-1])
                                parsenew.append(prlt)
                                subseqnew.append(subseqlt)
                    for s in range(1, d):
                        if d-s < 31:
                            psplit = maxlogpL[i+s-1][s] + pP[1] + Pbulgedist[d-s-1]
                            for nlt in RNAsequence[i+s:j+1]:
                                psplit += bulgesing_emissionsdict[nlt]
                            if abs(maxlogpP[j][d] - psplit) < 10e-13:
                                prlt = ["L"]
                                subseqlt = [[i+s-1, s]]
                                for u in range(0, d-s):
                                    prlt.append("n")
                                    subseqlt.append([i+s+u, 1])
                                    rebuild[i+s+u] = RNAsequence[i+s+u]
                                    reduc[i+s+u] = "."
                                parsenew.append(prlt)
                                subseqnew.append(subseqlt)
                    if abs(maxlogpP[j][d] - (maxlogpHL[j][d] + pP[3])) < 10e-13:
                        parsenew.append(["HL"])
                        subseqnew.append([[j, d]])
                    for s in range(1, d):
                        if abs(maxlogpP[j][d] - (maxlogpM1[i+s-1][s] + maxlogpM[j][d-s] + pP[4])) < 10e-13:
                            parsenew.append(["M1", "M"])
                            subseqnew.append([[i+s-1, s], [j, d-s]])
                    for a in range(0, M):
                        if abs(maxlogpP[j][d] - (maxlogpilloopMotifs[a][j][d] + pP[a+5])) < 10e-13:
                            parsenew.append(["KMotif " + str(a)])
                            subseqnew.append([[j, d]])
                #M
                if parse[t] == "M":
                    if d == 0:
                        pass
                    else:
                        if abs(maxlogpM[j][d] - (pM[1] + maxlogpR[j][d])) < 10e-13:
                            parsenew.append(["R"])
                            subseqnew.append([[j, d]])
                        for s in range(0, d-1):
                            if abs(maxlogpM[j][d] - (pM[0] + maxlogpM1[i+s][s+1] + maxlogpM[j][d-s-1])) < 10e-13:
                                parsenew.append(["M1", "M"])
                                subseqnew.append([[i+s, s+1], [j, d-s-1]])
                #R
                if parse[t] == "R":
                    if d == 0:
                        pass
                    else:
                        if abs(maxlogpR[j][d] - (maxlogpR[j-1][d-1] + n_emissionsdict[RNAsequence[j]] + pR[0])) < 10e-13:
                            parsenew.append(["R", "n"])
                            subseqnew.append([[j-1, d-1], [j, 1]])
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = "."
                        elif abs(maxlogpR[j][d] - (maxlogpM1[j][d] + pR[1])) < 10e-13:
                            parsenew.append(["M1"])
                            subseqnew.append([[j, d]])
                #M1
                if parse[t] == "M1":
                    if d == 0:
                        pass
                    else:
                        if abs(maxlogpM1[j][d] - (n_emissionsdict[RNAsequence[i]] + maxlogpM1[j][d-1] + pM1[0])) < 10e-13:
                            parsenew.append(["n", "M1"])
                            subseqnew.append([[i, 1], [j, d-1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "."
                        elif abs(maxlogpM1[j][d] - (maxlogpL[j][d] + pM1[1])) < 10e-13:
                            parsenew.append(["L"])
                            subseqnew.append([[j, d]])
                #Contiguous Blocks
                for a in range (0, N):
                    for g in range(0, len(hpPacket[a][0])):
                        if parse[t] == "Block " + str(a)+"."+str(g):
                            if g == 0:
                                if d == 0:
                                    pass
                                if d == 1:
                                    parsenew.append([hpPacket[a][0][-1].lower()])
                                    subseqnew.append([[j, d]])
                                    rebuild[i] = RNAsequence[i]
                                    reduc[i] = "x"
                            else:
                                if d == 0:
                                    parsenew.append(["Block " + str(a)+"."+str(g-1)])
                                    subseqnew.append([[j, d]])
                                elif d == 1:
                                    if abs(maxlogpcontigMC[a][g][j][d] - (maxlogpcontigMC[a][g-1][j][d-1] + letter_emissionsdict[hpPacket[a][0][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                        parsenew.append([hpPacket[a][0][-1-g].lower(), "Block " + str(a)+"."+str(g-1)])
                                        subseqnew.append([[i, 1], [j, d-1]])
                                        rebuild[i] = RNAsequence[i]
                                        reduc[i] = "x"
                                    elif abs(maxlogpcontigMC[a][g][j][d] - (maxlogpcontigMC[a][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                        parsenew.append(["Block " + str(a)+"."+str(g-1)])
                                        subseqnew.append([[j, d]])
            
                                else:
                                    if abs(maxlogpcontigMC[a][g][j][d] - (maxlogpcontigMC[a][g-1][j][d-1] + letter_emissionsdict[hpPacket[a][0][-1-g]][RNAsequence[i]] + pMotifNT[0])) < 10e-13:
                                        parsenew.append(["n", "Block " + str(a)+"."+str(g-1)])
                                        subseqnew.append([[i, 1], [j, d-1]])
                                        rebuild[i] = RNAsequence[i]
                                        reduc[i] = "x"
                                    elif abs(maxlogpcontigMC[a][g][j][d] - (maxlogpcontigMC[a][g-1][j][d] + pMotifNT[1])) < 10e-13:
                                        parsenew.append(["Block " + str(a)+"."+str(g-1)])
                                        subseqnew.append([[j, d]])
                                    for s in range(1, d):
                                        if abs(maxlogpcontigMC[a][g][j][d] - (letter_emissionsdict[hpPacket[a][0][-1-g]][RNAsequence[i]] + maxlogpinsertMC[hpPacket[a][0][-1-g]][i+s][s] + maxlogpcontigMC[a][g-1][j][d-s-1] + pMotifNT[2])) < 10e-13:
                                            parsenew.append(["n", "I"+hpPacket[a][0][-1-g], "Block " + str(a)+"."+str(g-1)])
                                            subseqnew.append([[i, 1], [i+s, s], [j, d-s-1]])
                                            rebuild[i] = RNAsequence[i]
                                            reduc[i] = "x"               
                #Insertions
                for let in letter_set:
                    if parse[t] == "I"+let:
                        if d == 0:
                            pass
                        elif d == 1:
                            parsenew.append(["n"])
                            subseqnew.append([[j, d]])
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = "x"
                        else:
                            parsenew.append(["n", "I"+let])
                            subseqnew.append([[i, 1], [j, d-1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "x"
                #Internal Loop Insertions
                for let in illetter_set:
                    if parse[t] == "ILI"+let:
                        if d == 0:
                            pass
                        elif d == 1:
                            parsenew.append(["n"])
                            subseqnew.append([[j, d]])
                            rebuild[j] = RNAsequence[j]
                            reduc[j] = "x"
                        else:
                            parsenew.append(["n", "ILI"+let])
                            subseqnew.append([[i, 1], [j, d-1]])
                            rebuild[i] = RNAsequence[i]
                            reduc[i] = "x"
                if parse[t] == "n":
                    parsenew.append(["n"])
                    subseqnew.append([[j, d]])
                if parse[t] == "s(":
                    parsenew.append(["s("])
                    subseqnew.append([[j, d]])
                if parse[t] == ")s":
                    parsenew.append([")s"])
                    subseqnew.append([[j, d]])
                if parse[t] == "X[":
                    parsenew.append(["X["])
                    subseqnew.append([[j, d]])
                if parse[t] == "]X":
                    parsenew.append(["]X"])
                    subseqnew.append([[j, d]])
                if parse[t] == "bp(":
                    parsenew.append(["bp("])
                    subseqnew.append([[j, d]])
                if parse[t] == ")bp":
                    parsenew.append([")bp"])
                    subseqnew.append([[j, d]])
            b = []
            for el in parsenew:
                for el1 in el:
                    b.append(el1)
            parse = b
            c = []
            for el in subseqnew:
                for el1 in el:
                    c.append(el1)
            subseq = c
        print(listtostr(reduc))
        print("")
        print(listtostr(rebuild))
    return listtostr(reduc)
